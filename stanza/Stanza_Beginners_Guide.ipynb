# %% [markdown]
# <a href="https://colab.research.google.com/github/zus12873/colab_notebooks/blob/main/stanza/Stanza_Beginners_Guide.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Stanza!
#
# ![Latest Version](https://img.shields.io/pypi/v/stanza.svg?colorB=bc4545)
# ![Python Versions](https://img.shields.io/pypi/pyversions/stanza.svg?colorB=bc4545)
#
# Stanza is a Python NLP toolkit that supports 60+ human languages. It is built with highly accurate neural network components that enable efficient training and evaluation with your own annotated data, and offers pretrained models on 100 treebanks. Additionally, Stanza provides a stable, officially maintained Python interface to Java Stanford CoreNLP Toolkit.
#
# In this tutorial, we will demonstrate how to set up Stanza and annotate text with its native neural network NLP models. For the use of the Python CoreNLP interface, please see other tutorials.

# %% [markdown]
# ## 1. Installing Stanza
#
# Note that Stanza only supports Python 3.6 and above. Installing and importing Stanza are as simple as running the following commands:

# %%
# Install; note that the prefix "!" is not needed if you are running in a terminal
# !pip install stanza

# Import the package
import stanza
# Out:
# Collecting stanza
#   Downloading stanza-1.10.1-py3-none-any.whl.metadata (13 kB)
# Collecting emoji (from stanza)
#   Downloading emoji-2.14.1-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from stanza) (1.26.4)
# Requirement already satisfied: protobuf>=3.15.0 in /usr/local/lib/python3.11/dist-packages (from stanza) (4.25.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from stanza) (2.32.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from stanza) (3.4.2)
# Requirement already satisfied: torch>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from stanza) (2.5.1+cu124)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from stanza) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (4.12.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.3.0->stanza)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.3.0->stanza)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.3.0->stanza) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (2025.1.31)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.3.0->stanza) (3.0.2)
# Downloading stanza-1.10.1-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 15.2 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 100.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 79.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 43.3 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.0 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.6 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.2 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 61.6 MB/s eta 0:00:00
# Downloading emoji-2.14.1-py3-none-any.whl (590 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 590.6/590.6 kB 34.5 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, emoji, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, stanza
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed emoji-2.14.1 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 stanza-1.10.1

# %% [markdown]
# ### More Information
#
# For common troubleshooting, please visit our [troubleshooting page](https://stanfordnlp.github.io/stanfordnlp/installation_usage.html#troubleshooting).

# %% [markdown]
# ## 2. Downloading Models
#
# You can download models with the `stanza.download` command. The language can be specified with either a full language name (e.g., "english"), or a short code (e.g., "en").
#
# By default, models will be saved to your `~/stanza_resources` directory. If you want to specify your own path to save the model files, you can pass a `dir=your_path` argument.

# %%
# Download an English model into the default directory
print("Downloading English model...")
stanza.download('en')

# Similarly, download a (simplified) Chinese model
# Note that you can use verbose=False to turn off all printed messages
print("Downloading Chinese model...")
stanza.download('zh', verbose=False)
# Out:
# Downloading English model...
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# INFO:stanza:Downloaded file to /root/stanza_resources/resources.json
# INFO:stanza:Downloading default packages for language: en (English) ...
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.10.0/models/default.zip:   0%|          | …
# INFO:stanza:Downloaded file to /root/stanza_resources/en/default.zip
# INFO:stanza:Finished downloading models and saved to /root/stanza_resources
# Downloading Chinese model...

# %% [markdown]
# ### More Information
#
# Pretrained models are provided for 60+ different languages. For all languages, available models and the corresponding short language codes, please check out the [models page](https://stanfordnlp.github.io/stanza/models.html).

# %% [markdown]
# ## 3. Processing Text

# %% [markdown]
# ### Constructing Pipeline
#
# To process a piece of text, you'll need to first construct a `Pipeline` with different `Processor` units. The pipeline is language-specific, so again you'll need to first specify the language (see examples).
#
# - By default, the pipeline will include all processors, including tokenization, multi-word token expansion, part-of-speech tagging, lemmatization, dependency parsing and named entity recognition (for supported languages). However, you can always specify what processors you want to include with the `processors` argument.
#
# - Stanza's pipeline is CUDA-aware, meaning that a CUDA-device will be used whenever it is available, otherwise CPUs will be used when a GPU is not found. You can force the pipeline to use CPU regardless by setting `use_gpu=False`.
#
# - Again, you can suppress all printed messages by setting `verbose=False`.

# %%
# Build an English pipeline, with all processors by default
print("Building an English pipeline...")
en_nlp = stanza.Pipeline('en')

# Build a Chinese pipeline, with customized processor list and no logging, and force it to use CPU
print("Building a Chinese pipeline...")
zh_nlp = stanza.Pipeline('zh', processors='tokenize,lemma,pos,depparse', verbose=False, use_gpu=False)
# Out:
# Building an English pipeline...
# Building a Chinese pipeline...

# %% [markdown]
# ### Annotating Text
#
# After a pipeline is successfully constructed, you can get annotations of a piece of text simply by passing the string into the pipeline object. The pipeline will return a `Document` object, which can be used to access detailed annotations from. For example:

# %%
# Processing English text
en_doc = en_nlp("Barack Obama was born in Hawaii.  He was elected president in 2008.")
print(type(en_doc))
raw_text="君諱泰，字元平，博陵安平人也。九空上襲，姜水濬其長瀾，四履宏開，營口口其曾構。西漢家嗣，見安於夏里，東京元舅，請交於亭伯。自玆以降，慶緒彌隆，庭孕之口，口盈口冕。高祖乗，弱冠有志氣，率性忠烈，後魏釋褐奉朝請光禄大夫、燕州刺史、冀州刺史、左光禄大夫、舞騎大將軍、儀同三司、使持節瀛定相三州諸軍事、定州刺史、侍中、尚書令、司徒公，謚曰靜穆公。曾祖仲哲，後魏龍讓將軍、主客侍郎、鎮遠將軍、營州口口、安平男，謚曰忠。理識沉隱，器懷貞尚，道映時倫，績宣朝伍。祖長瑜，浮陽郡守、太常卿，襲爵安平男。模楷指紳，羽儀廊廟，風移化洽，口屬於分符，禮備樂和，允彰於列棘。父子博，隋户部虞部侍郎、四州刺史。材標國幹，業口書林，效職文昌，百寮傾其雅範，攝官藩部，千里安其惠政。君積潤與原，資芳桂苑，岐嶷夙表，英徽早發。徑寸稱珍，方魏車而更重，盈尺爲寳，况秦城而取貴。孝敬之極，自叶天經，忠亮之規，非緣物獎。洎夫鈎深致遠，王室與銀編並究，屬辭比事，鸞光將鳳艷相輝。仁壽元年，應詔舉，射策甲第。時漢王諒光暦寵命，作牧參野。君以材地兼美，解巾爲漢府典籤。列長裾之賓從，預小山之文藻。高視梧宫，孤標龍岫。及燕謀且發，人馳成軫之辭，吴兵遂舉，家上周丘之策。君深體逆順，妙達機兆，屢陳忠講，因致猜嫌，遂以疾辭，免玆尤费。於是韬光衡泌，閉想簪纓，馳驚九流之宗，迴翔千載之表。氣積星頊，神清林澤。大業中，召補左武衛兵曹，非其好也。乃掛冠獨往，逃難他方。爰屬運初，委身從義，拜通議大夫，尋除監察御史。芬冠執憲，霜簡直筆，志存矯枉，情無屈橈。時以晉陽之地，王業攸基，餘寇未平，嚴城尚警。口奉口巡撫，式光原隰。遵塗北邁，兇黨南侵，君潛運謀猷，星馳表檄。大軍既至，羣袄遂口，特降璽書，深加慰喻，進授輕車都尉。武德五年，轉萬年縣丞。帝城貴要，口謂難繩，城里豪門，尤多私謁。君抗心奉法，正身直道，居職累載，聲譽甚隆。貞觀初，遷洛州長水縣令。中牟德被，遠慚馴雉，重泉政美，有娩翔驚。六年，遷蘇州司馬。同彦威之稱職，詛止文章，類儒宗之納善，實惟忠肅。嗟乎。南康仙駕，未戾於三山，壤口骥足，遠輟於千里。以貞觀十年十一月六日終於官所，年六十有一。夫人隴西李氏，籍慶高門，凝華中谷，貞姿玉映，淑問風揚。粤自移天，來儀君子，懋蘋繫於行潦，諧瑟琴於異室，女圖弘訓，母德馳芳。與善何愆，徂光奄謝。但故鄉絶人，先望遼遠，上下諮謀，改斯宅兆，爰卜邙洛，用定終居。粤以永徽六年十月一日合葬於洛州河南縣平樂鄉華邑里邙山之原。嗚呼哀哉。迺爲銘曰：天齊形勝，投釣開封。長岑博雅，弈葉雕龍。懷金鏘玉，疊構連峰。森梢良梓，磊落喬松。惟祖惟考，道風逾盛。績表遺縑，息孚留詠。懿哉君子，誕膺家慶。具美攸鍾，多能無競。始口窮運，終會昌辰。蘭臺振操，赤縣霑口。牛刀暫屈，驟足俄申。上才方遠，高春遽淪。猗歟令偶，蕙心瓊潔。昔奉齊眉，今歸同穴。口旗縈委，口扉冥滅。去矣佳城，悠哉芳烈。"
# Processing Chinese text
zh_doc = zh_nlp(raw_text)
print(type(zh_doc))
# Out:
# <class 'stanza.models.common.doc.Document'>
# <class 'stanza.models.common.doc.Document'>

# %%
zh_doc.sentences
# Out:
# [[
#    {
#      "id": 1,
#      "text": "君諱泰",
#      "lemma": "君諱泰",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 0,
#      "deprel": "root",
#      "start_char": 0,
#      "end_char": 3,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 2,
#      "text": "，",
#      "lemma": "，",
#      "upos": "PUNCT",
#      "xpos": ",",
#      "head": 3,
#      "deprel": "punct",
#      "start_char": 3,
#      "end_char": 4,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 3,
#      "text": "字元",
#      "lemma": "字元",
#      "upos": "NOUN",
#      "xpos": "NN",
#      "head": 1,
#      "deprel": "appos",
#      "start_char": 4,
#      "end_char": 6,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 4,
#      "text": "平",
#      "lemma": "平",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 1,
#      "deprel": "appos",
#      "start_char": 6,
#      "end_char": 7,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 5,
#      "text": "，",
#      "lemma": "，",
#      "upos": "PUNCT",
#      "xpos": ",",
#      "head": 8,
#      "deprel": "punct",
#      "start_char": 7,
#      "end_char": 8,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 6,
#      "text": "博陵",
#      "lemma": "博陵",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 8,
#      "deprel": "nmod",
#      "start_char": 8,
#      "end_char": 10,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 7,
#      "text": "安平",
#      "lemma": "安平",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 8,
#      "deprel": "compound",
#      "start_char": 10,
#      "end_char": 12,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 8,
#      "text": "人",
#      "lemma": "人",
#      "upos": "PART",
#      "xpos": "SFN",
#      "head": 1,
#      "deprel": "appos",
#      "start_char": 12,
#      "end_char": 13,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 9,
#      "text": "也",
#      "lemma": "也",
#      "upos": "SCONJ",
#      "xpos": "RB",
#      "head": 8,
#      "deprel": "mark",
#      "start_char": 13,
#      "end_char": 14,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 10,
#      "text": "。",
#      "lemma": "。",
#      "upos": "PUNCT",
#      "xpos": ".",
#      "head": 1,
#      "deprel": "punct",
#      "start_char": 14,
#      "end_char": 15,
#      "misc": "SpaceAfter=No"
#    }
#  ],
#  [
#    {
#      "id": 1,
#      "text": "九空",
#      "lemma": "九空",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 3,
#      "deprel": "nsubj",
#      "start_char": 15,
#      "end_char": 17,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 2,
#      "text": "上",
#      "lemma": "上",
#      "upos": "NOUN",
#      "xpos": "NN",
#      "head": 1,
#      "deprel": "acl",
#      "start_char": 17,
#      "end_char": 18,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 3,
#      "text": "襲",
#      "lemma": "襲",
#      "upos": "VERB",
#      "xpos": "VV",
#      "head": 0,
#      "deprel": "root",
#      "start_char": 18,
#      "end_char": 19,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 4,
#      "text": "，",
#      "lemma": "，",
#      "upos": "PUNCT",
#      "xpos": ",",
#      "head": 17,
#      "deprel": "punct",
#      "start_char": 19,
#      "end_char": 20,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 5,
#      "text": "姜",
#      "lemma": "姜",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 17,
#      "deprel": "nsubj",
#      "start_char": 20,
#      "end_char": 21,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 6,
#      "text": "水",
#      "lemma": "水",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 5,
#      "deprel": "flat:name",
#      "start_char": 21,
#      "end_char": 22,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 7,
#      "text": "濬",
#      "lemma": "濬",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 5,
#      "deprel": "flat:name",
#      "start_char": 22,
#      "end_char": 23,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 8,
#      "text": "其",
#      "lemma": "其",
#      "upos": "PRON",
#      "xpos": "PRP",
#      "feats": "Person=3",
#      "head": 5,
#      "deprel": "appos",
#      "start_char": 23,
#      "end_char": 24,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 9,
#      "text": "長",
#      "lemma": "長",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 5,
#      "deprel": "appos",
#      "start_char": 24,
#      "end_char": 25,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 10,
#      "text": "瀾",
#      "lemma": "瀾",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 9,
#      "deprel": "flat:name",
#      "start_char": 25,
#      "end_char": 26,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 11,
#      "text": "，",
#      "lemma": "，",
#      "upos": "PUNCT",
#      "xpos": ",",
#      "head": 13,
#      "deprel": "punct",
#      "start_char": 26,
#      "end_char": 27,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 12,
#      "text": "四",
#      "lemma": "四",
#      "upos": "NUM",
#      "xpos": "CD",
#      "feats": "NumType=Card",
#      "head": 13,
#      "deprel": "nummod",
#      "start_char": 27,
#      "end_char": 28,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 13,
#      "text": "履",
#      "lemma": "履",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 9,
#      "deprel": "conj",
#      "start_char": 28,
#      "end_char": 29,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 14,
#      "text": "宏開",
#      "lemma": "宏開",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 13,
#      "deprel": "flat:name",
#      "start_char": 29,
#      "end_char": 31,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 15,
#      "text": "，",
#      "lemma": "，",
#      "upos": "PUNCT",
#      "xpos": ",",
#      "head": 16,
#      "deprel": "punct",
#      "start_char": 31,
#      "end_char": 32,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 16,
#      "text": "營",
#      "lemma": "營",
#      "upos": "PART",
#      "xpos": "SFN",
#      "head": 5,
#      "deprel": "appos",
#      "start_char": 32,
#      "end_char": 33,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 17,
#      "text": "口口",
#      "lemma": "口口",
#      "upos": "VERB",
#      "xpos": "VV",
#      "head": 3,
#      "deprel": "parataxis",
#      "start_char": 33,
#      "end_char": 35,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 18,
#      "text": "其",
#      "lemma": "其",
#      "upos": "PRON",
#      "xpos": "PRP",
#      "feats": "Person=3",
#      "head": 20,
#      "deprel": "nsubj",
#      "start_char": 35,
#      "end_char": 36,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 19,
#      "text": "曾",
#      "lemma": "曾",
#      "upos": "ADV",
#      "xpos": "RB",
#      "head": 20,
#      "deprel": "advmod",
#      "start_char": 36,
#      "end_char": 37,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 20,
#      "text": "構",
#      "lemma": "構",
#      "upos": "VERB",
#      "xpos": "VV",
#      "head": 3,
#      "deprel": "parataxis",
#      "start_char": 37,
#      "end_char": 38,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 21,
#      "text": "。",
#      "lemma": "。",
#      "upos": "PUNCT",
#      "xpos": ".",
#      "head": 3,
#      "deprel": "punct",
#      "start_char": 38,
#      "end_char": 39,
#      "misc": "SpaceAfter=No"
#    }
#  ],
#  [
#    {
#      "id": 1,
#      "text": "西漢",
#      "lemma": "西漢",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 13,
#      "deprel": "nsubj",
#      "start_char": 39,
#      "end_char": 41,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 2,
#      "text": "家嗣",
#      "lemma": "家嗣",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 1,
#      "deprel": "flat:name",
#      "start_char": 41,
#      "end_char": 43,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 3,
#      "text": "，",
#      "lemma": "，",
#      "upos": "PUNCT",
#      "xpos": ",",
#      "head": 2,
#      "deprel": "punct",
#      "start_char": 43,
#      "end_char": 44,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 4,
#      "text": "見",
#      "lemma": "見",
#      "upos": "VERB",
#      "xpos": "VV",
#      "head": 13,
#      "deprel": "advcl",
#      "start_char": 44,
#      "end_char": 45,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 5,
#      "text": "安於",
#      "lemma": "安於",
#      "upos": "VERB",
#      "xpos": "VV",
#      "head": 4,
#      "deprel": "xcomp",
#      "start_char": 45,
#      "end_char": 47,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 6,
#      "text": "夏里",
#      "lemma": "夏里",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 5,
#      "deprel": "obj",
#      "start_char": 47,
#      "end_char": 49,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 7,
#      "text": "，",
#      "lemma": "，",
#      "upos": "PUNCT",
#      "xpos": ",",
#      "head": 4,
#      "deprel": "punct",
#      "start_char": 49,
#      "end_char": 50,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 8,
#      "text": "東",
#      "lemma": "東",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 11,
#      "deprel": "nmod",
#      "start_char": 50,
#      "end_char": 51,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 9,
#      "text": "京",
#      "lemma": "京",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 11,
#      "deprel": "nmod",
#      "start_char": 51,
#      "end_char": 52,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 10,
#      "text": "元",
#      "lemma": "元",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 11,
#      "deprel": "compound",
#      "start_char": 52,
#      "end_char": 53,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 11,
#      "text": "舅",
#      "lemma": "舅",
#      "upos": "PART",
#      "xpos": "SFN",
#      "head": 13,
#      "deprel": "nsubj",
#      "start_char": 53,
#      "end_char": 54,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 12,
#      "text": "，",
#      "lemma": "，",
#      "upos": "PUNCT",
#      "xpos": ",",
#      "head": 4,
#      "deprel": "punct",
#      "start_char": 54,
#      "end_char": 55,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 13,
#      "text": "請",
#      "lemma": "請",
#      "upos": "VERB",
#      "xpos": "VV",
#      "head": 0,
#      "deprel": "root",
#      "start_char": 55,
#      "end_char": 56,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 14,
#      "text": "交於亭伯",
#      "lemma": "交於亭伯",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 13,
#      "deprel": "obj",
#      "start_char": 56,
#      "end_char": 60,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 15,
#      "text": "。",
#      "lemma": "。",
#      "upos": "PUNCT",
#      "xpos": ".",
#      "head": 13,
#      "deprel": "punct",
#      "start_char": 60,
#      "end_char": 61,
#      "misc": "SpaceAfter=No"
#    }
#  ],
#  [
#    {
#      "id": 1,
#      "text": "自",
#      "lemma": "自",
#      "upos": "ADP",
#      "xpos": "IN",
#      "head": 3,
#      "deprel": "case",
#      "start_char": 61,
#      "end_char": 62,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 2,
#      "text": "玆",
#      "lemma": "玆",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 3,
#      "deprel": "nsubj",
#      "start_char": 62,
#      "end_char": 63,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 3,
#      "text": "以",
#      "lemma": "以",
#      "upos": "VERB",
#      "xpos": "VV",
#      "feats": "Voice=Cau",
#      "head": 15,
#      "deprel": "ccomp",
#      "start_char": 63,
#      "end_char": 64,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 4,
#      "text": "降",
#      "lemma": "降",
#      "upos": "VERB",
#      "xpos": "VV",
#      "head": 3,
#      "deprel": "xcomp",
#      "start_char": 64,
#      "end_char": 65,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 5,
#      "text": "，",
#      "lemma": "，",
#      "upos": "PUNCT",
#      "xpos": ",",
#      "head": 3,
#      "deprel": "punct",
#      "start_char": 65,
#      "end_char": 66,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 6,
#      "text": "慶",
#      "lemma": "慶",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 12,
#      "deprel": "nmod",
#      "start_char": 66,
#      "end_char": 67,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 7,
#      "text": "緒",
#      "lemma": "緒",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 6,
#      "deprel": "flat:name",
#      "start_char": 67,
#      "end_char": 68,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 8,
#      "text": "彌隆",
#      "lemma": "彌隆",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 6,
#      "deprel": "appos",
#      "start_char": 68,
#      "end_char": 70,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 9,
#      "text": "，",
#      "lemma": "，",
#      "upos": "PUNCT",
#      "xpos": ",",
#      "head": 12,
#      "deprel": "punct",
#      "start_char": 70,
#      "end_char": 71,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 10,
#      "text": "庭孕",
#      "lemma": "庭孕",
#      "upos": "VERB",
#      "xpos": "VV",
#      "head": 12,
#      "deprel": "acl:relcl",
#      "start_char": 71,
#      "end_char": 73,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 11,
#      "text": "之",
#      "lemma": "之",
#      "upos": "SCONJ",
#      "xpos": "DEC",
#      "head": 10,
#      "deprel": "mark:rel",
#      "start_char": 73,
#      "end_char": 74,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 12,
#      "text": "口",
#      "lemma": "口",
#      "upos": "NOUN",
#      "xpos": "NN",
#      "head": 15,
#      "deprel": "nsubj",
#      "start_char": 74,
#      "end_char": 75,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 13,
#      "text": "，",
#      "lemma": "，",
#      "upos": "PUNCT",
#      "xpos": ",",
#      "head": 12,
#      "deprel": "punct",
#      "start_char": 75,
#      "end_char": 76,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 14,
#      "text": "口盈",
#      "lemma": "口盈",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 15,
#      "deprel": "nsubj",
#      "start_char": 76,
#      "end_char": 78,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 15,
#      "text": "口冕",
#      "lemma": "口冕",
#      "upos": "VERB",
#      "xpos": "VV",
#      "head": 0,
#      "deprel": "root",
#      "start_char": 78,
#      "end_char": 80,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 16,
#      "text": "。",
#      "lemma": "。",
#      "upos": "PUNCT",
#      "xpos": ".",
#      "head": 15,
#      "deprel": "punct",
#      "start_char": 80,
#      "end_char": 81,
#      "misc": "SpaceAfter=No"
#    }
#  ],
#  [
#    {
#      "id": 1,
#      "text": "高祖",
#      "lemma": "高祖",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 16,
#      "deprel": "nsubj",
#      "start_char": 81,
#      "end_char": 83,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 2,
#      "text": "乗",
#      "lemma": "乗",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 1,
#      "deprel": "flat:name",
#      "start_char": 83,
#      "end_char": 84,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 3,
#      "text": "，",
#      "lemma": "，",
#      "upos": "PUNCT",
#      "xpos": ",",
#      "head": 4,
#      "deprel": "punct",
#      "start_char": 84,
#      "end_char": 85,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 4,
#      "text": "弱",
#      "lemma": "弱",
#      "upos": "ADJ",
#      "xpos": "JJ",
#      "head": 6,
#      "deprel": "advcl",
#      "start_char": 85,
#      "end_char": 86,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 5,
#      "text": "冠",
#      "lemma": "冠",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 4,
#      "deprel": "flat:name",
#      "start_char": 86,
#      "end_char": 87,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 6,
#      "text": "有",
#      "lemma": "有",
#      "upos": "VERB",
#      "xpos": "VV",
#      "head": 16,
#      "deprel": "advcl",
#      "start_char": 87,
#      "end_char": 88,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 7,
#      "text": "志氣",
#      "lemma": "志氣",
#      "upos": "NOUN",
#      "xpos": "NN",
#      "head": 6,
#      "deprel": "obj",
#      "start_char": 88,
#      "end_char": 90,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 8,
#      "text": "，",
#      "lemma": "，",
#      "upos": "PUNCT",
#      "xpos": ",",
#      "head": 6,
#      "deprel": "punct",
#      "start_char": 90,
#      "end_char": 91,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 9,
#      "text": "率性",
#      "lemma": "率性",
#      "upos": "VERB",
#      "xpos": "VV",
#      "head": 16,
#      "deprel": "advcl",
#      "start_char": 91,
#      "end_char": 93,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 10,
#      "text": "忠烈",
#      "lemma": "忠烈",
#      "upos": "NOUN",
#      "xpos": "NN",
#      "head": 6,
#      "deprel": "obj",
#      "start_char": 93,
#      "end_char": 95,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 11,
#      "text": "，",
#      "lemma": "，",
#      "upos": "PUNCT",
#      "xpos": ",",
#      "head": 9,
#      "deprel": "punct",
#      "start_char": 95,
#      "end_char": 96,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 12,
#      "text": "後",
#      "lemma": "後",
#      "upos": "ADV",
#      "xpos": "RB",
#      "head": 16,
#      "deprel": "advmod",
#      "start_char": 96,
#      "end_char": 97,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 13,
#      "text": "魏",
#      "lemma": "魏",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 16,
#      "deprel": "nsubj",
#      "start_char": 97,
#      "end_char": 98,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 14,
#      "text": "釋",
#      "lemma": "釋",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 13,
#      "deprel": "flat:name",
#      "start_char": 98,
#      "end_char": 99,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 15,
#      "text": "褐",
#      "lemma": "褐",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 14,
#      "deprel": "flat:name",
#      "start_char": 99,
#      "end_char": 100,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 16,
#      "text": "奉",
#      "lemma": "奉",
#      "upos": "VERB",
#      "xpos": "VV",
#      "feats": "Voice=Cau",
#      "head": 0,
#      "deprel": "root",
#      "start_char": 100,
#      "end_char": 101,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 17,
#      "text": "朝",
#      "lemma": "朝",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 18,
#      "deprel": "nmod",
#      "start_char": 101,
#      "end_char": 102,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 18,
#      "text": "請",
#      "lemma": "請",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 16,
#      "deprel": "obj",
#      "start_char": 102,
#      "end_char": 103,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 19,
#      "text": "光禄",
#      "lemma": "光禄",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 18,
#      "deprel": "conj",
#      "start_char": 103,
#      "end_char": 105,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 20,
#      "text": "大夫",
#      "lemma": "大夫",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 18,
#      "deprel": "flat:name",
#      "start_char": 105,
#      "end_char": 107,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 21,
#      "text": "、",
#      "lemma": "、",
#      "upos": "PUNCT",
#      "xpos": "EC",
#      "head": 23,
#      "deprel": "punct",
#      "start_char": 107,
#      "end_char": 108,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 22,
#      "text": "燕州",
#      "lemma": "燕州",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 23,
#      "deprel": "nmod",
#      "start_char": 108,
#      "end_char": 110,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 23,
#      "text": "刺史",
#      "lemma": "刺史",
#      "upos": "NOUN",
#      "xpos": "NN",
#      "head": 18,
#      "deprel": "conj",
#      "start_char": 110,
#      "end_char": 112,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 24,
#      "text": "、",
#      "lemma": "、",
#      "upos": "PUNCT",
#      "xpos": "EC",
#      "head": 26,
#      "deprel": "punct",
#      "start_char": 112,
#      "end_char": 113,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 25,
#      "text": "冀州",
#      "lemma": "冀州",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 26,
#      "deprel": "nmod",
#      "start_char": 113,
#      "end_char": 115,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 26,
#      "text": "刺史",
#      "lemma": "刺史",
#      "upos": "NOUN",
#      "xpos": "NN",
#      "head": 18,
#      "deprel": "conj",
#      "start_char": 115,
#      "end_char": 117,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 27,
#      "text": "、",
#      "lemma": "、",
#      "upos": "PUNCT",
#      "xpos": "EC",
#      "head": 30,
#      "deprel": "punct",
#      "start_char": 117,
#      "end_char": 118,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 28,
#      "text": "左",
#      "lemma": "左",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 30,
#      "deprel": "nmod",
#      "start_char": 118,
#      "end_char": 119,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 29,
#      "text": "光禄",
#      "lemma": "光禄",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 30,
#      "deprel": "nmod",
#      "start_char": 119,
#      "end_char": 121,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 30,
#      "text": "大夫",
#      "lemma": "大夫",
#      "upos": "NOUN",
#      "xpos": "NN",
#      "head": 18,
#      "deprel": "conj",
#      "start_char": 121,
#      "end_char": 123,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 31,
#      "text": "、",
#      "lemma": "、",
#      "upos": "PUNCT",
#      "xpos": "EC",
#      "head": 36,
#      "deprel": "punct",
#      "start_char": 123,
#      "end_char": 124,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 32,
#      "text": "舞",
#      "lemma": "舞",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 36,
#      "deprel": "nmod",
#      "start_char": 124,
#      "end_char": 125,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 33,
#      "text": "騎",
#      "lemma": "騎",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 36,
#      "deprel": "nmod",
#      "start_char": 125,
#      "end_char": 126,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 34,
#      "text": "大",
#      "lemma": "大",
#      "upos": "PART",
#      "xpos": "PFA",
#      "head": 35,
#      "deprel": "case",
#      "start_char": 126,
#      "end_char": 127,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 35,
#      "text": "將",
#      "lemma": "將",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 36,
#      "deprel": "compound",
#      "start_char": 127,
#      "end_char": 128,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 36,
#      "text": "軍",
#      "lemma": "軍",
#      "upos": "PART",
#      "xpos": "SFN",
#      "head": 18,
#      "deprel": "conj",
#      "start_char": 128,
#      "end_char": 129,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 37,
#      "text": "、",
#      "lemma": "、",
#      "upos": "PUNCT",
#      "xpos": "EC",
#      "head": 41,
#      "deprel": "punct",
#      "start_char": 129,
#      "end_char": 130,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 38,
#      "text": "儀",
#      "lemma": "儀",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 41,
#      "deprel": "nmod",
#      "start_char": 130,
#      "end_char": 131,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 39,
#      "text": "同",
#      "lemma": "同",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 41,
#      "deprel": "nmod",
#      "start_char": 131,
#      "end_char": 132,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 40,
#      "text": "三",
#      "lemma": "三",
#      "upos": "NUM",
#      "xpos": "CD",
#      "feats": "NumType=Card",
#      "head": 41,
#      "deprel": "nummod",
#      "start_char": 132,
#      "end_char": 133,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 41,
#      "text": "司",
#      "lemma": "司",
#      "upos": "NOUN",
#      "xpos": "NN",
#      "head": 18,
#      "deprel": "conj",
#      "start_char": 133,
#      "end_char": 134,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 42,
#      "text": "、",
#      "lemma": "、",
#      "upos": "PUNCT",
#      "xpos": "EC",
#      "head": 43,
#      "deprel": "punct",
#      "start_char": 134,
#      "end_char": 135,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 43,
#      "text": "使持",
#      "lemma": "使持",
#      "upos": "VERB",
#      "xpos": "VV",
#      "head": 46,
#      "deprel": "advcl",
#      "start_char": 135,
#      "end_char": 137,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 44,
#      "text": "節",
#      "lemma": "節",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 43,
#      "deprel": "obj",
#      "start_char": 137,
#      "end_char": 138,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 45,
#      "text": "瀛",
#      "lemma": "瀛",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 44,
#      "deprel": "flat:name",
#      "start_char": 138,
#      "end_char": 139,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 46,
#      "text": "定相",
#      "lemma": "定相",
#      "upos": "VERB",
#      "xpos": "VV",
#      "head": 51,
#      "deprel": "acl:relcl",
#      "start_char": 139,
#      "end_char": 141,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 47,
#      "text": "三",
#      "lemma": "三",
#      "upos": "NUM",
#      "xpos": "CD",
#      "feats": "NumType=Card",
#      "head": 48,
#      "deprel": "nummod",
#      "start_char": 141,
#      "end_char": 142,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 48,
#      "text": "州",
#      "lemma": "州",
#      "upos": "NOUN",
#      "xpos": "NN",
#      "head": 51,
#      "deprel": "nmod",
#      "start_char": 142,
#      "end_char": 143,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 49,
#      "text": "諸",
#      "lemma": "諸",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 51,
#      "deprel": "nmod",
#      "start_char": 143,
#      "end_char": 144,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 50,
#      "text": "軍",
#      "lemma": "軍",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 51,
#      "deprel": "compound",
#      "start_char": 144,
#      "end_char": 145,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 51,
#      "text": "事",
#      "lemma": "事",
#      "upos": "PART",
#      "xpos": "SFN",
#      "head": 18,
#      "deprel": "conj",
#      "start_char": 145,
#      "end_char": 146,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 52,
#      "text": "、",
#      "lemma": "、",
#      "upos": "PUNCT",
#      "xpos": "EC",
#      "head": 54,
#      "deprel": "punct",
#      "start_char": 146,
#      "end_char": 147,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 53,
#      "text": "定州",
#      "lemma": "定州",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 54,
#      "deprel": "nmod",
#      "start_char": 147,
#      "end_char": 149,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 54,
#      "text": "刺史",
#      "lemma": "刺史",
#      "upos": "NOUN",
#      "xpos": "NN",
#      "head": 18,
#      "deprel": "conj",
#      "start_char": 149,
#      "end_char": 151,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 55,
#      "text": "、",
#      "lemma": "、",
#      "upos": "PUNCT",
#      "xpos": "EC",
#      "head": 56,
#      "deprel": "punct",
#      "start_char": 151,
#      "end_char": 152,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 56,
#      "text": "侍中",
#      "lemma": "侍中",
#      "upos": "NOUN",
#      "xpos": "NN",
#      "head": 51,
#      "deprel": "conj",
#      "start_char": 152,
#      "end_char": 154,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 57,
#      "text": "、",
#      "lemma": "、",
#      "upos": "PUNCT",
#      "xpos": "EC",
#      "head": 58,
#      "deprel": "punct",
#      "start_char": 154,
#      "end_char": 155,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 58,
#      "text": "尚",
#      "lemma": "尚",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 56,
#      "deprel": "conj",
#      "start_char": 155,
#      "end_char": 156,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 59,
#      "text": "書",
#      "lemma": "書",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 60,
#      "deprel": "compound",
#      "start_char": 156,
#      "end_char": 157,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 60,
#      "text": "令",
#      "lemma": "令",
#      "upos": "PART",
#      "xpos": "SFN",
#      "head": 18,
#      "deprel": "conj",
#      "start_char": 157,
#      "end_char": 158,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 61,
#      "text": "、",
#      "lemma": "、",
#      "upos": "PUNCT",
#      "xpos": "EC",
#      "head": 63,
#      "deprel": "punct",
#      "start_char": 158,
#      "end_char": 159,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 62,
#      "text": "司徒",
#      "lemma": "司徒",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 63,
#      "deprel": "compound",
#      "start_char": 159,
#      "end_char": 161,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 63,
#      "text": "公",
#      "lemma": "公",
#      "upos": "PART",
#      "xpos": "SFN",
#      "head": 18,
#      "deprel": "conj",
#      "start_char": 161,
#      "end_char": 162,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 64,
#      "text": "，",
#      "lemma": "，",
#      "upos": "PUNCT",
#      "xpos": ",",
#      "head": 65,
#      "deprel": "punct",
#      "start_char": 162,
#      "end_char": 163,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 65,
#      "text": "謚",
#      "lemma": "謚",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 63,
#      "deprel": "compound",
#      "start_char": 163,
#      "end_char": 164,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 66,
#      "text": "曰",
#      "lemma": "曰",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 65,
#      "deprel": "flat:name",
#      "start_char": 164,
#      "end_char": 165,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 67,
#      "text": "靜",
#      "lemma": "靜",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 65,
#      "deprel": "conj",
#      "start_char": 165,
#      "end_char": 166,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 68,
#      "text": "穆公",
#      "lemma": "穆公",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 67,
#      "deprel": "flat:name",
#      "start_char": 166,
#      "end_char": 168,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 69,
#      "text": "。",
#      "lemma": "。",
#      "upos": "PUNCT",
#      "xpos": ".",
#      "head": 16,
#      "deprel": "punct",
#      "start_char": 168,
#      "end_char": 169,
#      "misc": "SpaceAfter=No"
#    }
#  ],
#  [
#    {
#      "id": 1,
#      "text": "曾",
#      "lemma": "曾",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 0,
#      "deprel": "root",
#      "start_char": 169,
#      "end_char": 170,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 2,
#      "text": "祖",
#      "lemma": "祖",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 1,
#      "deprel": "flat:name",
#      "start_char": 170,
#      "end_char": 171,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 3,
#      "text": "仲",
#      "lemma": "仲",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 1,
#      "deprel": "flat:name",
#      "start_char": 171,
#      "end_char": 172,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 4,
#      "text": "哲",
#      "lemma": "哲",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 1,
#      "deprel": "flat:name",
#      "start_char": 172,
#      "end_char": 173,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 5,
#      "text": "，",
#      "lemma": "，",
#      "upos": "PUNCT",
#      "xpos": ",",
#      "head": 9,
#      "deprel": "punct",
#      "start_char": 173,
#      "end_char": 174,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 6,
#      "text": "後",
#      "lemma": "後",
#      "upos": "ADV",
#      "xpos": "RB",
#      "head": 9,
#      "deprel": "advmod",
#      "start_char": 174,
#      "end_char": 175,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 7,
#      "text": "魏龍",
#      "lemma": "魏龍",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 9,
#      "deprel": "nmod",
#      "start_char": 175,
#      "end_char": 177,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 8,
#      "text": "讓將",
#      "lemma": "讓將",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 7,
#      "deprel": "flat:name",
#      "start_char": 177,
#      "end_char": 179,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 9,
#      "text": "軍",
#      "lemma": "軍",
#      "upos": "PART",
#      "xpos": "SFN",
#      "head": 1,
#      "deprel": "appos",
#      "start_char": 179,
#      "end_char": 180,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 10,
#      "text": "、",
#      "lemma": "、",
#      "upos": "PUNCT",
#      "xpos": "EC",
#      "head": 13,
#      "deprel": "punct",
#      "start_char": 180,
#      "end_char": 181,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 11,
#      "text": "主",
#      "lemma": "主",
#      "upos": "PART",
#      "xpos": "PFA",
#      "head": 12,
#      "deprel": "case",
#      "start_char": 181,
#      "end_char": 182,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 12,
#      "text": "客侍",
#      "lemma": "客侍",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 13,
#      "deprel": "compound",
#      "start_char": 182,
#      "end_char": 184,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 13,
#      "text": "郎",
#      "lemma": "郎",
#      "upos": "PART",
#      "xpos": "SFN",
#      "head": 9,
#      "deprel": "conj",
#      "start_char": 184,
#      "end_char": 185,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 14,
#      "text": "、",
#      "lemma": "、",
#      "upos": "PUNCT",
#      "xpos": "EC",
#      "head": 17,
#      "deprel": "punct",
#      "start_char": 185,
#      "end_char": 186,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 15,
#      "text": "鎮遠",
#      "lemma": "鎮遠",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 17,
#      "deprel": "nmod",
#      "start_char": 186,
#      "end_char": 188,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 16,
#      "text": "將",
#      "lemma": "將",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 17,
#      "deprel": "compound",
#      "start_char": 188,
#      "end_char": 189,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 17,
#      "text": "軍",
#      "lemma": "軍",
#      "upos": "PART",
#      "xpos": "SFN",
#      "head": 9,
#      "deprel": "conj",
#      "start_char": 189,
#      "end_char": 190,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 18,
#      "text": "、",
#      "lemma": "、",
#      "upos": "PUNCT",
#      "xpos": "EC",
#      "head": 21,
#      "deprel": "punct",
#      "start_char": 190,
#      "end_char": 191,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 19,
#      "text": "營州",
#      "lemma": "營州",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 20,
#      "deprel": "compound",
#      "start_char": 191,
#      "end_char": 193,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 20,
#      "text": "口",
#      "lemma": "口",
#      "upos": "PART",
#      "xpos": "SFN",
#      "head": 21,
#      "deprel": "compound",
#      "start_char": 193,
#      "end_char": 194,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 21,
#      "text": "口",
#      "lemma": "口",
#      "upos": "PART",
#      "xpos": "SFN",
#      "head": 9,
#      "deprel": "conj",
#      "start_char": 194,
#      "end_char": 195,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 22,
#      "text": "、",
#      "lemma": "、",
#      "upos": "PUNCT",
#      "xpos": "EC",
#      "head": 24,
#      "deprel": "punct",
#      "start_char": 195,
#      "end_char": 196,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 23,
#      "text": "安平",
#      "lemma": "安平",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 24,
#      "deprel": "compound",
#      "start_char": 196,
#      "end_char": 198,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 24,
#      "text": "男",
#      "lemma": "男",
#      "upos": "PART",
#      "xpos": "SFN",
#      "head": 9,
#      "deprel": "conj",
#      "start_char": 198,
#      "end_char": 199,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 25,
#      "text": "，",
#      "lemma": "，",
#      "upos": "PUNCT",
#      "xpos": ",",
#      "head": 26,
#      "deprel": "punct",
#      "start_char": 199,
#      "end_char": 200,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 26,
#      "text": "謚",
#      "lemma": "謚",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 9,
#      "deprel": "conj",
#      "start_char": 200,
#      "end_char": 201,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 27,
#      "text": "曰忠",
#      "lemma": "曰忠",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 26,
#      "deprel": "flat:name",
#      "start_char": 201,
#      "end_char": 203,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 28,
#      "text": "。",
#      "lemma": "。",
#      "upos": "PUNCT",
#      "xpos": ".",
#      "head": 1,
#      "deprel": "punct",
#      "start_char": 203,
#      "end_char": 204,
#      "misc": "SpaceAfter=No"
#    }
#  ],
#  [
#    {
#      "id": 1,
#      "text": "理識",
#      "lemma": "理識",
#      "upos": "VERB",
#      "xpos": "VV",
#      "head": 2,
#      "deprel": "advcl",
#      "start_char": 204,
#      "end_char": 206,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 2,
#      "text": "沉隱",
#      "lemma": "沉隱",
#      "upos": "ADJ",
#      "xpos": "JJ",
#      "head": 8,
#      "deprel": "advcl",
#      "start_char": 206,
#      "end_char": 208,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 3,
#      "text": "，",
#      "lemma": "，",
#      "upos": "PUNCT",
#      "xpos": ",",
#      "head": 2,
#      "deprel": "punct",
#      "start_char": 208,
#      "end_char": 209,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 4,
#      "text": "器",
#      "lemma": "器",
#      "upos": "PART",
#      "xpos": "SFN",
#      "head": 8,
#      "deprel": "nsubj",
#      "start_char": 209,
#      "end_char": 210,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 5,
#      "text": "懷貞",
#      "lemma": "懷貞",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 4,
#      "deprel": "appos",
#      "start_char": 210,
#      "end_char": 212,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 6,
#      "text": "尚",
#      "lemma": "尚",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 5,
#      "deprel": "flat:name",
#      "start_char": 212,
#      "end_char": 213,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 7,
#      "text": "，",
#      "lemma": "，",
#      "upos": "PUNCT",
#      "xpos": ",",
#      "head": 4,
#      "deprel": "punct",
#      "start_char": 213,
#      "end_char": 214,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 8,
#      "text": "道映",
#      "lemma": "道映",
#      "upos": "VERB",
#      "xpos": "VV",
#      "head": 0,
#      "deprel": "root",
#      "start_char": 214,
#      "end_char": 216,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 9,
#      "text": "時",
#      "lemma": "時",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 8,
#      "deprel": "obj",
#      "start_char": 216,
#      "end_char": 217,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 10,
#      "text": "倫",
#      "lemma": "倫",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 9,
#      "deprel": "flat:name",
#      "start_char": 217,
#      "end_char": 218,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 11,
#      "text": "，",
#      "lemma": "，",
#      "upos": "PUNCT",
#      "xpos": ",",
#      "head": 12,
#      "deprel": "punct",
#      "start_char": 218,
#      "end_char": 219,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 12,
#      "text": "績宣",
#      "lemma": "績宣",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 8,
#      "deprel": "parataxis",
#      "start_char": 219,
#      "end_char": 221,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 13,
#      "text": "朝伍",
#      "lemma": "朝伍",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 12,
#      "deprel": "flat:name",
#      "start_char": 221,
#      "end_char": 223,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 14,
#      "text": "。",
#      "lemma": "。",
#      "upos": "PUNCT",
#      "xpos": ".",
#      "head": 8,
#      "deprel": "punct",
#      "start_char": 223,
#      "end_char": 224,
#      "misc": "SpaceAfter=No"
#    }
#  ],
#  [
#    {
#      "id": 1,
#      "text": "祖",
#      "lemma": "祖",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 10,
#      "deprel": "nsubj",
#      "start_char": 224,
#      "end_char": 225,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 2,
#      "text": "長瑜",
#      "lemma": "長瑜",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 1,
#      "deprel": "flat:name",
#      "start_char": 225,
#      "end_char": 227,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 3,
#      "text": "，",
#      "lemma": "，",
#      "upos": "PUNCT",
#      "xpos": ",",
#      "head": 5,
#      "deprel": "punct",
#      "start_char": 227,
#      "end_char": 228,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 4,
#      "text": "浮陽",
#      "lemma": "浮陽",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 5,
#      "deprel": "nmod",
#      "start_char": 228,
#      "end_char": 230,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 5,
#      "text": "郡守",
#      "lemma": "郡守",
#      "upos": "NOUN",
#      "xpos": "NN",
#      "head": 1,
#      "deprel": "appos",
#      "start_char": 230,
#      "end_char": 232,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 6,
#      "text": "、",
#      "lemma": "、",
#      "upos": "PUNCT",
#      "xpos": "EC",
#      "head": 8,
#      "deprel": "punct",
#      "start_char": 232,
#      "end_char": 233,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 7,
#      "text": "太常",
#      "lemma": "太常",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 8,
#      "deprel": "compound",
#      "start_char": 233,
#      "end_char": 235,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 8,
#      "text": "卿",
#      "lemma": "卿",
#      "upos": "PART",
#      "xpos": "SFN",
#      "head": 1,
#      "deprel": "conj",
#      "start_char": 235,
#      "end_char": 236,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 9,
#      "text": "，",
#      "lemma": "，",
#      "upos": "PUNCT",
#      "xpos": ",",
#      "head": 1,
#      "deprel": "punct",
#      "start_char": 236,
#      "end_char": 237,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 10,
#      "text": "襲爵",
#      "lemma": "襲爵",
#      "upos": "VERB",
#      "xpos": "VV",
#      "head": 0,
#      "deprel": "root",
#      "start_char": 237,
#      "end_char": 239,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 11,
#      "text": "安平",
#      "lemma": "安平",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 12,
#      "deprel": "compound",
#      "start_char": 239,
#      "end_char": 241,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 12,
#      "text": "男",
#      "lemma": "男",
#      "upos": "PART",
#      "xpos": "SFN",
#      "head": 10,
#      "deprel": "obj",
#      "start_char": 241,
#      "end_char": 242,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 13,
#      "text": "。",
#      "lemma": "。",
#      "upos": "PUNCT",
#      "xpos": ".",
#      "head": 10,
#      "deprel": "punct",
#      "start_char": 242,
#      "end_char": 243,
#      "misc": "SpaceAfter=No"
#    }
#  ],
#  [
#    {
#      "id": 1,
#      "text": "模楷",
#      "lemma": "模楷",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 11,
#      "deprel": "nsubj",
#      "start_char": 243,
#      "end_char": 245,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 2,
#      "text": "指紳",
#      "lemma": "指紳",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 1,
#      "deprel": "flat:name",
#      "start_char": 245,
#      "end_char": 247,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 3,
#      "text": "，",
#      "lemma": "，",
#      "upos": "PUNCT",
#      "xpos": ",",
#      "head": 5,
#      "deprel": "punct",
#      "start_char": 247,
#      "end_char": 248,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 4,
#      "text": "羽儀",
#      "lemma": "羽儀",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 5,
#      "deprel": "compound",
#      "start_char": 248,
#      "end_char": 250,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 5,
#      "text": "廊廟",
#      "lemma": "廊廟",
#      "upos": "PART",
#      "xpos": "SFN",
#      "head": 1,
#      "deprel": "appos",
#      "start_char": 250,
#      "end_char": 252,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 6,
#      "text": "，",
#      "lemma": "，",
#      "upos": "PUNCT",
#      "xpos": ",",
#      "head": 1,
#      "deprel": "punct",
#      "start_char": 252,
#      "end_char": 253,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 7,
#      "text": "風",
#      "lemma": "風",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 9,
#      "deprel": "nsubj",
#      "start_char": 253,
#      "end_char": 254,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 8,
#      "text": "移化",
#      "lemma": "移化",
#      "upos": "VERB",
#      "xpos": "VV",
#      "head": 9,
#      "deprel": "advcl",
#      "start_char": 254,
#      "end_char": 256,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 9,
#      "text": "洽",
#      "lemma": "洽",
#      "upos": "VERB",
#      "xpos": "VV",
#      "head": 11,
#      "deprel": "advcl",
#      "start_char": 256,
#      "end_char": 257,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 10,
#      "text": "，",
#      "lemma": "，",
#      "upos": "PUNCT",
#      "xpos": ",",
#      "head": 9,
#      "deprel": "punct",
#      "start_char": 257,
#      "end_char": 258,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 11,
#      "text": "口屬",
#      "lemma": "口屬",
#      "upos": "VERB",
#      "xpos": "VV",
#      "head": 0,
#      "deprel": "root",
#      "start_char": 258,
#      "end_char": 260,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 12,
#      "text": "於",
#      "lemma": "於",
#      "upos": "VERB",
#      "xpos": "VV",
#      "head": 11,
#      "deprel": "mark",
#      "start_char": 260,
#      "end_char": 261,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 13,
#      "text": "分符",
#      "lemma": "分符",
#      "upos": "VERB",
#      "xpos": "VV",
#      "head": 11,
#      "deprel": "xcomp",
#      "start_char": 261,
#      "end_char": 263,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 14,
#      "text": "，",
#      "lemma": "，",
#      "upos": "PUNCT",
#      "xpos": ",",
#      "head": 20,
#      "deprel": "punct",
#      "start_char": 263,
#      "end_char": 264,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 15,
#      "text": "禮",
#      "lemma": "禮",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 20,
#      "deprel": "nsubj",
#      "start_char": 264,
#      "end_char": 265,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 16,
#      "text": "備",
#      "lemma": "備",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 15,
#      "deprel": "flat:name",
#      "start_char": 265,
#      "end_char": 266,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 17,
#      "text": "樂",
#      "lemma": "樂",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 15,
#      "deprel": "conj",
#      "start_char": 266,
#      "end_char": 267,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 18,
#      "text": "和",
#      "lemma": "和",
#      "upos": "CCONJ",
#      "xpos": "CC",
#      "head": 20,
#      "deprel": "cc",
#      "start_char": 267,
#      "end_char": 268,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 19,
#      "text": "，",
#      "lemma": "，",
#      "upos": "PUNCT",
#      "xpos": ",",
#      "head": 20,
#      "deprel": "punct",
#      "start_char": 268,
#      "end_char": 269,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 20,
#      "text": "允彰",
#      "lemma": "允彰",
#      "upos": "VERB",
#      "xpos": "VV",
#      "head": 11,
#      "deprel": "parataxis",
#      "start_char": 269,
#      "end_char": 271,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 21,
#      "text": "於",
#      "lemma": "於",
#      "upos": "VERB",
#      "xpos": "VV",
#      "head": 20,
#      "deprel": "mark",
#      "start_char": 271,
#      "end_char": 272,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 22,
#      "text": "列棘",
#      "lemma": "列棘",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 20,
#      "deprel": "obj",
#      "start_char": 272,
#      "end_char": 274,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 23,
#      "text": "。",
#      "lemma": "。",
#      "upos": "PUNCT",
#      "xpos": ".",
#      "head": 11,
#      "deprel": "punct",
#      "start_char": 274,
#      "end_char": 275,
#      "misc": "SpaceAfter=No"
#    }
#  ],
#  [
#    {
#      "id": 1,
#      "text": "父子",
#      "lemma": "父子",
#      "upos": "NOUN",
#      "xpos": "NN",
#      "head": 2,
#      "deprel": "compound",
#      "start_char": 275,
#      "end_char": 277,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 2,
#      "text": "博",
#      "lemma": "博",
#      "upos": "PART",
#      "xpos": "SFN",
#      "head": 0,
#      "deprel": "root",
#      "start_char": 277,
#      "end_char": 278,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 3,
#      "text": "，",
#      "lemma": "，",
#      "upos": "PUNCT",
#      "xpos": ",",
#      "head": 6,
#      "deprel": "punct",
#      "start_char": 278,
#      "end_char": 279,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 4,
#      "text": "隋户",
#      "lemma": "隋户",
#      "upos": "NOUN",
#      "xpos": "NN",
#      "head": 6,
#      "deprel": "nmod",
#      "start_char": 279,
#      "end_char": 281,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 5,
#      "text": "部虞",
#      "lemma": "部虞",
#      "upos": "NOUN",
#      "xpos": "NN",
#      "head": 6,
#      "deprel": "nmod",
#      "start_char": 281,
#      "end_char": 283,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 6,
#      "text": "部侍郎",
#      "lemma": "部侍郎",
#      "upos": "NOUN",
#      "xpos": "NN",
#      "head": 2,
#      "deprel": "conj",
#      "start_char": 283,
#      "end_char": 286,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 7,
#      "text": "、",
#      "lemma": "、",
#      "upos": "PUNCT",
#      "xpos": "EC",
#      "head": 10,
#      "deprel": "punct",
#      "start_char": 286,
#      "end_char": 287,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 8,
#      "text": "四",
#      "lemma": "四",
#      "upos": "NUM",
#      "xpos": "CD",
#      "feats": "NumType=Card",
#      "head": 9,
#      "deprel": "nummod",
#      "start_char": 287,
#      "end_char": 288,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 9,
#      "text": "州",
#      "lemma": "州",
#      "upos": "NOUN",
#      "xpos": "NN",
# ...
#      "misc": "SpaceAfter=No"
#    }
#  ],
#  [
#    {
#      "id": 1,
#      "text": "懿",
#      "lemma": "懿",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 5,
#      "deprel": "nsubj",
#      "start_char": 1094,
#      "end_char": 1095,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 2,
#      "text": "哉",
#      "lemma": "哉",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 1,
#      "deprel": "flat:name",
#      "start_char": 1095,
#      "end_char": 1096,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 3,
#      "text": "君子",
#      "lemma": "君子",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 1,
#      "deprel": "flat:name",
#      "start_char": 1096,
#      "end_char": 1098,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 4,
#      "text": "，",
#      "lemma": "，",
#      "upos": "PUNCT",
#      "xpos": ",",
#      "head": 1,
#      "deprel": "punct",
#      "start_char": 1098,
#      "end_char": 1099,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 5,
#      "text": "誕",
#      "lemma": "誕",
#      "upos": "VERB",
#      "xpos": "VV",
#      "head": 0,
#      "deprel": "root",
#      "start_char": 1099,
#      "end_char": 1100,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 6,
#      "text": "膺",
#      "lemma": "膺",
#      "upos": "VERB",
#      "xpos": "VV",
#      "head": 5,
#      "deprel": "mark",
#      "start_char": 1100,
#      "end_char": 1101,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 7,
#      "text": "家慶",
#      "lemma": "家慶",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 6,
#      "deprel": "obj",
#      "start_char": 1101,
#      "end_char": 1103,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 8,
#      "text": "。",
#      "lemma": "。",
#      "upos": "PUNCT",
#      "xpos": ".",
#      "head": 5,
#      "deprel": "punct",
#      "start_char": 1103,
#      "end_char": 1104,
#      "misc": "SpaceAfter=No"
#    }
#  ],
#  [
#    {
#      "id": 1,
#      "text": "具",
#      "lemma": "具",
#      "upos": "VERB",
#      "xpos": "VV",
#      "head": 7,
#      "deprel": "advcl",
#      "start_char": 1104,
#      "end_char": 1105,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 2,
#      "text": "美",
#      "lemma": "美",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 1,
#      "deprel": "obj",
#      "start_char": 1105,
#      "end_char": 1106,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 3,
#      "text": "攸鍾",
#      "lemma": "攸鍾",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 2,
#      "deprel": "appos",
#      "start_char": 1106,
#      "end_char": 1108,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 4,
#      "text": "，",
#      "lemma": "，",
#      "upos": "PUNCT",
#      "xpos": ",",
#      "head": 1,
#      "deprel": "punct",
#      "start_char": 1108,
#      "end_char": 1109,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 5,
#      "text": "多",
#      "lemma": "多",
#      "upos": "ADV",
#      "xpos": "RB",
#      "head": 7,
#      "deprel": "advmod",
#      "start_char": 1109,
#      "end_char": 1110,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 6,
#      "text": "能",
#      "lemma": "能",
#      "upos": "AUX",
#      "xpos": "MD",
#      "head": 7,
#      "deprel": "aux",
#      "start_char": 1110,
#      "end_char": 1111,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 7,
#      "text": "無競",
#      "lemma": "無競",
#      "upos": "VERB",
#      "xpos": "VV",
#      "head": 0,
#      "deprel": "root",
#      "start_char": 1111,
#      "end_char": 1113,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 8,
#      "text": "。",
#      "lemma": "。",
#      "upos": "PUNCT",
#      "xpos": ".",
#      "head": 7,
#      "deprel": "punct",
#      "start_char": 1113,
#      "end_char": 1114,
#      "misc": "SpaceAfter=No"
#    }
#  ],
#  [
#    {
#      "id": 1,
#      "text": "始口",
#      "lemma": "始口",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 2,
#      "deprel": "nsubj",
#      "start_char": 1114,
#      "end_char": 1116,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 2,
#      "text": "窮",
#      "lemma": "窮",
#      "upos": "VERB",
#      "xpos": "VV",
#      "head": 3,
#      "deprel": "advcl",
#      "start_char": 1116,
#      "end_char": 1117,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 3,
#      "text": "運",
#      "lemma": "運",
#      "upos": "VERB",
#      "xpos": "VV",
#      "head": 0,
#      "deprel": "root",
#      "start_char": 1117,
#      "end_char": 1118,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 4,
#      "text": "，",
#      "lemma": "，",
#      "upos": "PUNCT",
#      "xpos": ",",
#      "head": 6,
#      "deprel": "punct",
#      "start_char": 1118,
#      "end_char": 1119,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 5,
#      "text": "終",
#      "lemma": "終",
#      "upos": "ADV",
#      "xpos": "RB",
#      "head": 6,
#      "deprel": "advmod",
#      "start_char": 1119,
#      "end_char": 1120,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 6,
#      "text": "會",
#      "lemma": "會",
#      "upos": "PART",
#      "xpos": "SFN",
#      "head": 3,
#      "deprel": "parataxis",
#      "start_char": 1120,
#      "end_char": 1121,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 7,
#      "text": "昌辰",
#      "lemma": "昌辰",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 6,
#      "deprel": "appos",
#      "start_char": 1121,
#      "end_char": 1123,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 8,
#      "text": "。",
#      "lemma": "。",
#      "upos": "PUNCT",
#      "xpos": ".",
#      "head": 3,
#      "deprel": "punct",
#      "start_char": 1123,
#      "end_char": 1124,
#      "misc": "SpaceAfter=No"
#    }
#  ],
#  [
#    {
#      "id": 1,
#      "text": "蘭",
#      "lemma": "蘭",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 3,
#      "deprel": "nsubj",
#      "start_char": 1124,
#      "end_char": 1125,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 2,
#      "text": "臺",
#      "lemma": "臺",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 1,
#      "deprel": "flat:name",
#      "start_char": 1125,
#      "end_char": 1126,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 3,
#      "text": "振操",
#      "lemma": "振操",
#      "upos": "VERB",
#      "xpos": "VV",
#      "head": 0,
#      "deprel": "root",
#      "start_char": 1126,
#      "end_char": 1128,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 4,
#      "text": "，",
#      "lemma": "，",
#      "upos": "PUNCT",
#      "xpos": ",",
#      "head": 6,
#      "deprel": "punct",
#      "start_char": 1128,
#      "end_char": 1129,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 5,
#      "text": "赤縣",
#      "lemma": "赤縣",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 6,
#      "deprel": "nmod",
#      "start_char": 1129,
#      "end_char": 1131,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 6,
#      "text": "霑口",
#      "lemma": "霑口",
#      "upos": "NOUN",
#      "xpos": "NN",
#      "head": 3,
#      "deprel": "parataxis",
#      "start_char": 1131,
#      "end_char": 1133,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 7,
#      "text": "。",
#      "lemma": "。",
#      "upos": "PUNCT",
#      "xpos": ".",
#      "head": 3,
#      "deprel": "punct",
#      "start_char": 1133,
#      "end_char": 1134,
#      "misc": "SpaceAfter=No"
#    }
#  ],
#  [
#    {
#      "id": 1,
#      "text": "牛刀",
#      "lemma": "牛刀",
#      "upos": "NOUN",
#      "xpos": "NN",
#      "head": 5,
#      "deprel": "nsubj",
#      "start_char": 1134,
#      "end_char": 1136,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 2,
#      "text": "暫",
#      "lemma": "暫",
#      "upos": "ADV",
#      "xpos": "RB",
#      "head": 3,
#      "deprel": "advmod",
#      "start_char": 1136,
#      "end_char": 1137,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 3,
#      "text": "屈",
#      "lemma": "屈",
#      "upos": "VERB",
#      "xpos": "VV",
#      "head": 5,
#      "deprel": "advcl",
#      "start_char": 1137,
#      "end_char": 1138,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 4,
#      "text": "，",
#      "lemma": "，",
#      "upos": "PUNCT",
#      "xpos": ",",
#      "head": 3,
#      "deprel": "punct",
#      "start_char": 1138,
#      "end_char": 1139,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 5,
#      "text": "驟",
#      "lemma": "驟",
#      "upos": "VERB",
#      "xpos": "VV",
#      "head": 0,
#      "deprel": "root",
#      "start_char": 1139,
#      "end_char": 1140,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 6,
#      "text": "足",
#      "lemma": "足",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 5,
#      "deprel": "obj",
#      "start_char": 1140,
#      "end_char": 1141,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 7,
#      "text": "俄申",
#      "lemma": "俄申",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 6,
#      "deprel": "flat:name",
#      "start_char": 1141,
#      "end_char": 1143,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 8,
#      "text": "。",
#      "lemma": "。",
#      "upos": "PUNCT",
#      "xpos": ".",
#      "head": 5,
#      "deprel": "punct",
#      "start_char": 1143,
#      "end_char": 1144,
#      "misc": "SpaceAfter=No"
#    }
#  ],
#  [
#    {
#      "id": 1,
#      "text": "上",
#      "lemma": "上",
#      "upos": "NOUN",
#      "xpos": "NN",
#      "head": 6,
#      "deprel": "nmod:tmod",
#      "start_char": 1144,
#      "end_char": 1145,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 2,
#      "text": "才",
#      "lemma": "才",
#      "upos": "SCONJ",
#      "xpos": "RB",
#      "head": 6,
#      "deprel": "mark",
#      "start_char": 1145,
#      "end_char": 1146,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 3,
#      "text": "方遠",
#      "lemma": "方遠",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 6,
#      "deprel": "nsubj",
#      "start_char": 1146,
#      "end_char": 1148,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 4,
#      "text": "，",
#      "lemma": "，",
#      "upos": "PUNCT",
#      "xpos": ",",
#      "head": 1,
#      "deprel": "punct",
#      "start_char": 1148,
#      "end_char": 1149,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 5,
#      "text": "高春遽",
#      "lemma": "高春遽",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 6,
#      "deprel": "nsubj",
#      "start_char": 1149,
#      "end_char": 1152,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 6,
#      "text": "淪",
#      "lemma": "淪",
#      "upos": "VERB",
#      "xpos": "VV",
#      "head": 0,
#      "deprel": "root",
#      "start_char": 1152,
#      "end_char": 1153,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 7,
#      "text": "。",
#      "lemma": "。",
#      "upos": "PUNCT",
#      "xpos": ".",
#      "head": 6,
#      "deprel": "punct",
#      "start_char": 1153,
#      "end_char": 1154,
#      "misc": "SpaceAfter=No"
#    }
#  ],
#  [
#    {
#      "id": 1,
#      "text": "猗",
#      "lemma": "猗",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 3,
#      "deprel": "nsubj",
#      "start_char": 1154,
#      "end_char": 1155,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 2,
#      "text": "歟",
#      "lemma": "歟",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 1,
#      "deprel": "flat:name",
#      "start_char": 1155,
#      "end_char": 1156,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 3,
#      "text": "令偶",
#      "lemma": "令偶",
#      "upos": "VERB",
#      "xpos": "VV",
#      "head": 0,
#      "deprel": "root",
#      "start_char": 1156,
#      "end_char": 1158,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 4,
#      "text": "，",
#      "lemma": "，",
#      "upos": "PUNCT",
#      "xpos": ",",
#      "head": 5,
#      "deprel": "punct",
#      "start_char": 1158,
#      "end_char": 1159,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 5,
#      "text": "蕙心",
#      "lemma": "蕙心",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 3,
#      "deprel": "parataxis",
#      "start_char": 1159,
#      "end_char": 1161,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 6,
#      "text": "瓊潔",
#      "lemma": "瓊潔",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 5,
#      "deprel": "flat:name",
#      "start_char": 1161,
#      "end_char": 1163,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 7,
#      "text": "。",
#      "lemma": "。",
#      "upos": "PUNCT",
#      "xpos": ".",
#      "head": 3,
#      "deprel": "punct",
#      "start_char": 1163,
#      "end_char": 1164,
#      "misc": "SpaceAfter=No"
#    }
#  ],
#  [
#    {
#      "id": 1,
#      "text": "昔奉",
#      "lemma": "昔奉",
#      "upos": "VERB",
#      "xpos": "VV",
#      "head": 12,
#      "deprel": "advcl",
#      "start_char": 1164,
#      "end_char": 1166,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 2,
#      "text": "齊眉",
#      "lemma": "齊眉",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 1,
#      "deprel": "obj",
#      "start_char": 1166,
#      "end_char": 1168,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 3,
#      "text": "，",
#      "lemma": "，",
#      "upos": "PUNCT",
#      "xpos": ",",
#      "head": 1,
#      "deprel": "punct",
#      "start_char": 1168,
#      "end_char": 1169,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 4,
#      "text": "今",
#      "lemma": "今",
#      "upos": "NOUN",
#      "xpos": "NN",
#      "head": 5,
#      "deprel": "nmod:tmod",
#      "start_char": 1169,
#      "end_char": 1170,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 5,
#      "text": "歸",
#      "lemma": "歸",
#      "upos": "VERB",
#      "xpos": "VV",
#      "head": 12,
#      "deprel": "advcl",
#      "start_char": 1170,
#      "end_char": 1171,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 6,
#      "text": "同穴",
#      "lemma": "同穴",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 5,
#      "deprel": "obj",
#      "start_char": 1171,
#      "end_char": 1173,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 7,
#      "text": "。",
#      "lemma": "。",
#      "upos": "PUNCT",
#      "xpos": ".",
#      "head": 5,
#      "deprel": "punct",
#      "start_char": 1173,
#      "end_char": 1174,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 8,
#      "text": "口旗",
#      "lemma": "口旗",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 9,
#      "deprel": "nmod",
#      "start_char": 1174,
#      "end_char": 1176,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 9,
#      "text": "縈委",
#      "lemma": "縈委",
#      "upos": "NOUN",
#      "xpos": "NN",
#      "head": 12,
#      "deprel": "nsubj",
#      "start_char": 1176,
#      "end_char": 1178,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 10,
#      "text": "，",
#      "lemma": "，",
#      "upos": "PUNCT",
#      "xpos": ",",
#      "head": 5,
#      "deprel": "punct",
#      "start_char": 1178,
#      "end_char": 1179,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 11,
#      "text": "口扉",
#      "lemma": "口扉",
#      "upos": "VERB",
#      "xpos": "VV",
#      "head": 12,
#      "deprel": "advcl",
#      "start_char": 1179,
#      "end_char": 1181,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 12,
#      "text": "冥滅",
#      "lemma": "冥滅",
#      "upos": "VERB",
#      "xpos": "VV",
#      "head": 0,
#      "deprel": "root",
#      "start_char": 1181,
#      "end_char": 1183,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 13,
#      "text": "。",
#      "lemma": "。",
#      "upos": "PUNCT",
#      "xpos": ".",
#      "head": 12,
#      "deprel": "punct",
#      "start_char": 1183,
#      "end_char": 1184,
#      "misc": "SpaceAfter=No"
#    }
#  ],
#  [
#    {
#      "id": 1,
#      "text": "去",
#      "lemma": "去",
#      "upos": "VERB",
#      "xpos": "VV",
#      "head": 0,
#      "deprel": "root",
#      "start_char": 1184,
#      "end_char": 1185,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 2,
#      "text": "矣佳",
#      "lemma": "矣佳",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 3,
#      "deprel": "compound",
#      "start_char": 1185,
#      "end_char": 1187,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 3,
#      "text": "城",
#      "lemma": "城",
#      "upos": "PART",
#      "xpos": "SFN",
#      "head": 1,
#      "deprel": "obj",
#      "start_char": 1187,
#      "end_char": 1188,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 4,
#      "text": "，",
#      "lemma": "，",
#      "upos": "PUNCT",
#      "xpos": ",",
#      "head": 5,
#      "deprel": "punct",
#      "start_char": 1188,
#      "end_char": 1189,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 5,
#      "text": "悠哉芳烈",
#      "lemma": "悠哉芳烈",
#      "upos": "PROPN",
#      "xpos": "NNP",
#      "head": 3,
#      "deprel": "conj",
#      "start_char": 1189,
#      "end_char": 1193,
#      "misc": "SpaceAfter=No"
#    },
#    {
#      "id": 6,
#      "text": "。",
#      "lemma": "。",
#      "upos": "PUNCT",
#      "xpos": ".",
#      "head": 1,
#      "deprel": "punct",
#      "start_char": 1193,
#      "end_char": 1194,
#      "misc": "SpaceAfter=No"
#    }
#  ]]

# %% [markdown]
# ### More Information
#
# For more information on how to construct a pipeline and information on different processors, please visit our [pipeline page](https://stanfordnlp.github.io/stanfordnlp/pipeline.html).

# %% [markdown]
# ## 4. Accessing Annotations
#
# Annotations can be accessed from the returned `Document` object.
#
# A `Document` contains a list of `Sentence`s, and a `Sentence` contains a list of `Token`s and `Word`s. For the most part `Token`s and `Word`s overlap, but some tokens can be divided into mutiple words, for instance the French token `aux` is divided into the words `à` and `les`, while in English a word and a token are equivalent. Note that dependency parses are derived over `Word`s.
#
# Additionally, a `Span` object is used to represent annotations that are part of a document, such as named entity mentions.
#
#
# The following example iterate over all English sentences and words, and print the word information one by one:

# %%
for i, sent in enumerate(en_doc.sentences):
    print("[Sentence {}]".format(i+1))
    for word in sent.words:
        print("{:12s}\t{:12s}\t{:6s}\t{:d}\t{:12s}".format(\
              word.text, word.lemma, word.pos, word.head, word.deprel))
    print("")

# %% [markdown]
# The following example iterate over all extracted named entity mentions and print out their character spans and types.

# %%
print("Mention text\tType\tStart-End")
for ent in en_doc.ents:
    print("{}\t{}\t{}-{}".format(ent.text, ent.type, ent.start_char, ent.end_char))

# %% [markdown]
# And similarly for the Chinese text:

# %%
for i, sent in enumerate(zh_doc.sentences):
    print("[Sentence {}]".format(i+1))
    for word in sent.words:
        print("{:12s}\t{:12s}\t{:6s}\t{:d}\t{:12s}".format(\
              word.text, word.lemma, word.pos, word.head, word.deprel))
    print("")
# Out:
# [Sentence 1]
# 君諱泰         	君諱泰         	PROPN 	0	root
# ，           	，           	PUNCT 	3	punct
# 字元          	字元          	NOUN  	1	appos
# 平           	平           	PROPN 	1	appos
# ，           	，           	PUNCT 	8	punct
# 博陵          	博陵          	PROPN 	8	nmod
# 安平          	安平          	PROPN 	8	compound
# 人           	人           	PART  	1	appos
# 也           	也           	SCONJ 	8	mark
# 。           	。           	PUNCT 	1	punct
#
# [Sentence 2]
# 九空          	九空          	PROPN 	3	nsubj
# 上           	上           	NOUN  	1	acl
# 襲           	襲           	VERB  	0	root
# ，           	，           	PUNCT 	17	punct
# 姜           	姜           	PROPN 	17	nsubj
# 水           	水           	PROPN 	5	flat:name
# 濬           	濬           	PROPN 	5	flat:name
# 其           	其           	PRON  	5	appos
# 長           	長           	PROPN 	5	appos
# 瀾           	瀾           	PROPN 	9	flat:name
# ，           	，           	PUNCT 	13	punct
# 四           	四           	NUM   	13	nummod
# 履           	履           	PROPN 	9	conj
# 宏開          	宏開          	PROPN 	13	flat:name
# ，           	，           	PUNCT 	16	punct
# 營           	營           	PART  	5	appos
# 口口          	口口          	VERB  	3	parataxis
# 其           	其           	PRON  	20	nsubj
# 曾           	曾           	ADV   	20	advmod
# 構           	構           	VERB  	3	parataxis
# 。           	。           	PUNCT 	3	punct
#
# [Sentence 3]
# 西漢          	西漢          	PROPN 	13	nsubj
# 家嗣          	家嗣          	PROPN 	1	flat:name
# ，           	，           	PUNCT 	2	punct
# 見           	見           	VERB  	13	advcl
# 安於          	安於          	VERB  	4	xcomp
# 夏里          	夏里          	PROPN 	5	obj
# ，           	，           	PUNCT 	4	punct
# 東           	東           	PROPN 	11	nmod
# 京           	京           	PROPN 	11	nmod
# 元           	元           	PROPN 	11	compound
# 舅           	舅           	PART  	13	nsubj
# ，           	，           	PUNCT 	4	punct
# 請           	請           	VERB  	0	root
# 交於亭伯        	交於亭伯        	PROPN 	13	obj
# 。           	。           	PUNCT 	13	punct
#
# [Sentence 4]
# 自           	自           	ADP   	3	case
# 玆           	玆           	PROPN 	3	nsubj
# 以           	以           	VERB  	15	ccomp
# 降           	降           	VERB  	3	xcomp
# ，           	，           	PUNCT 	3	punct
# 慶           	慶           	PROPN 	12	nmod
# 緒           	緒           	PROPN 	6	flat:name
# 彌隆          	彌隆          	PROPN 	6	appos
# ，           	，           	PUNCT 	12	punct
# 庭孕          	庭孕          	VERB  	12	acl:relcl
# 之           	之           	SCONJ 	10	mark:rel
# 口           	口           	NOUN  	15	nsubj
# ，           	，           	PUNCT 	12	punct
# 口盈          	口盈          	PROPN 	15	nsubj
# 口冕          	口冕          	VERB  	0	root
# 。           	。           	PUNCT 	15	punct
#
# [Sentence 5]
# 高祖          	高祖          	PROPN 	16	nsubj
# 乗           	乗           	PROPN 	1	flat:name
# ，           	，           	PUNCT 	4	punct
# 弱           	弱           	ADJ   	6	advcl
# 冠           	冠           	PROPN 	4	flat:name
# 有           	有           	VERB  	16	advcl
# 志氣          	志氣          	NOUN  	6	obj
# ，           	，           	PUNCT 	6	punct
# 率性          	率性          	VERB  	16	advcl
# 忠烈          	忠烈          	NOUN  	6	obj
# ，           	，           	PUNCT 	9	punct
# 後           	後           	ADV   	16	advmod
# 魏           	魏           	PROPN 	16	nsubj
# 釋           	釋           	PROPN 	13	flat:name
# 褐           	褐           	PROPN 	14	flat:name
# 奉           	奉           	VERB  	0	root
# 朝           	朝           	PROPN 	18	nmod
# 請           	請           	PROPN 	16	obj
# 光禄          	光禄          	PROPN 	18	conj
# 大夫          	大夫          	PROPN 	18	flat:name
# 、           	、           	PUNCT 	23	punct
# 燕州          	燕州          	PROPN 	23	nmod
# 刺史          	刺史          	NOUN  	18	conj
# 、           	、           	PUNCT 	26	punct
# 冀州          	冀州          	PROPN 	26	nmod
# 刺史          	刺史          	NOUN  	18	conj
# 、           	、           	PUNCT 	30	punct
# 左           	左           	PROPN 	30	nmod
# 光禄          	光禄          	PROPN 	30	nmod
# 大夫          	大夫          	NOUN  	18	conj
# 、           	、           	PUNCT 	36	punct
# 舞           	舞           	PROPN 	36	nmod
# 騎           	騎           	PROPN 	36	nmod
# 大           	大           	PART  	35	case
# 將           	將           	PROPN 	36	compound
# 軍           	軍           	PART  	18	conj
# 、           	、           	PUNCT 	41	punct
# 儀           	儀           	PROPN 	41	nmod
# 同           	同           	PROPN 	41	nmod
# 三           	三           	NUM   	41	nummod
# 司           	司           	NOUN  	18	conj
# 、           	、           	PUNCT 	43	punct
# 使持          	使持          	VERB  	46	advcl
# 節           	節           	PROPN 	43	obj
# 瀛           	瀛           	PROPN 	44	flat:name
# 定相          	定相          	VERB  	51	acl:relcl
# 三           	三           	NUM   	48	nummod
# 州           	州           	NOUN  	51	nmod
# 諸           	諸           	PROPN 	51	nmod
# 軍           	軍           	PROPN 	51	compound
# 事           	事           	PART  	18	conj
# 、           	、           	PUNCT 	54	punct
# 定州          	定州          	PROPN 	54	nmod
# 刺史          	刺史          	NOUN  	18	conj
# 、           	、           	PUNCT 	56	punct
# 侍中          	侍中          	NOUN  	51	conj
# 、           	、           	PUNCT 	58	punct
# 尚           	尚           	PROPN 	56	conj
# 書           	書           	PROPN 	60	compound
# 令           	令           	PART  	18	conj
# 、           	、           	PUNCT 	63	punct
# 司徒          	司徒          	PROPN 	63	compound
# 公           	公           	PART  	18	conj
# ，           	，           	PUNCT 	65	punct
# 謚           	謚           	PROPN 	63	compound
# 曰           	曰           	PROPN 	65	flat:name
# 靜           	靜           	PROPN 	65	conj
# 穆公          	穆公          	PROPN 	67	flat:name
# 。           	。           	PUNCT 	16	punct
#
# [Sentence 6]
# 曾           	曾           	PROPN 	0	root
# 祖           	祖           	PROPN 	1	flat:name
# 仲           	仲           	PROPN 	1	flat:name
# 哲           	哲           	PROPN 	1	flat:name
# ，           	，           	PUNCT 	9	punct
# 後           	後           	ADV   	9	advmod
# 魏龍          	魏龍          	PROPN 	9	nmod
# 讓將          	讓將          	PROPN 	7	flat:name
# 軍           	軍           	PART  	1	appos
# 、           	、           	PUNCT 	13	punct
# 主           	主           	PART  	12	case
# 客侍          	客侍          	PROPN 	13	compound
# 郎           	郎           	PART  	9	conj
# 、           	、           	PUNCT 	17	punct
# 鎮遠          	鎮遠          	PROPN 	17	nmod
# 將           	將           	PROPN 	17	compound
# 軍           	軍           	PART  	9	conj
# 、           	、           	PUNCT 	21	punct
# 營州          	營州          	PROPN 	20	compound
# 口           	口           	PART  	21	compound
# 口           	口           	PART  	9	conj
# 、           	、           	PUNCT 	24	punct
# 安平          	安平          	PROPN 	24	compound
# 男           	男           	PART  	9	conj
# ，           	，           	PUNCT 	26	punct
# 謚           	謚           	PROPN 	9	conj
# 曰忠          	曰忠          	PROPN 	26	flat:name
# 。           	。           	PUNCT 	1	punct
#
# [Sentence 7]
# 理識          	理識          	VERB  	2	advcl
# 沉隱          	沉隱          	ADJ   	8	advcl
# ，           	，           	PUNCT 	2	punct
# 器           	器           	PART  	8	nsubj
# 懷貞          	懷貞          	PROPN 	4	appos
# 尚           	尚           	PROPN 	5	flat:name
# ，           	，           	PUNCT 	4	punct
# 道映          	道映          	VERB  	0	root
# 時           	時           	PROPN 	8	obj
# 倫           	倫           	PROPN 	9	flat:name
# ，           	，           	PUNCT 	12	punct
# 績宣          	績宣          	PROPN 	8	parataxis
# 朝伍          	朝伍          	PROPN 	12	flat:name
# 。           	。           	PUNCT 	8	punct
#
# [Sentence 8]
# 祖           	祖           	PROPN 	10	nsubj
# 長瑜          	長瑜          	PROPN 	1	flat:name
# ，           	，           	PUNCT 	5	punct
# 浮陽          	浮陽          	PROPN 	5	nmod
# 郡守          	郡守          	NOUN  	1	appos
# 、           	、           	PUNCT 	8	punct
# 太常          	太常          	PROPN 	8	compound
# 卿           	卿           	PART  	1	conj
# ，           	，           	PUNCT 	1	punct
# 襲爵          	襲爵          	VERB  	0	root
# 安平          	安平          	PROPN 	12	compound
# 男           	男           	PART  	10	obj
# 。           	。           	PUNCT 	10	punct
#
# [Sentence 9]
# 模楷          	模楷          	PROPN 	11	nsubj
# 指紳          	指紳          	PROPN 	1	flat:name
# ，           	，           	PUNCT 	5	punct
# 羽儀          	羽儀          	PROPN 	5	compound
# 廊廟          	廊廟          	PART  	1	appos
# ，           	，           	PUNCT 	1	punct
# 風           	風           	PROPN 	9	nsubj
# 移化          	移化          	VERB  	9	advcl
# 洽           	洽           	VERB  	11	advcl
# ，           	，           	PUNCT 	9	punct
# 口屬          	口屬          	VERB  	0	root
# 於           	於           	VERB  	11	mark
# 分符          	分符          	VERB  	11	xcomp
# ，           	，           	PUNCT 	20	punct
# 禮           	禮           	PROPN 	20	nsubj
# 備           	備           	PROPN 	15	flat:name
# 樂           	樂           	PROPN 	15	conj
# 和           	和           	CCONJ 	20	cc
# ，           	，           	PUNCT 	20	punct
# 允彰          	允彰          	VERB  	11	parataxis
# 於           	於           	VERB  	20	mark
# 列棘          	列棘          	PROPN 	20	obj
# 。           	。           	PUNCT 	11	punct
#
# [Sentence 10]
# 父子          	父子          	NOUN  	2	compound
# 博           	博           	PART  	0	root
# ，           	，           	PUNCT 	6	punct
# 隋户          	隋户          	NOUN  	6	nmod
# 部虞          	部虞          	NOUN  	6	nmod
# 部侍郎         	部侍郎         	NOUN  	2	conj
# 、           	、           	PUNCT 	10	punct
# 四           	四           	NUM   	9	nummod
# 州           	州           	NOUN  	10	nmod
# 刺史          	刺史          	NOUN  	2	conj
# 。           	。           	PUNCT 	2	punct
#
# [Sentence 11]
# 材標          	材標          	PROPN 	3	nmod
# 國           	國           	PROPN 	3	compound
# 幹           	幹           	PART  	12	nsubj
# ，           	，           	PUNCT 	5	punct
# 業口          	業口          	PROPN 	3	appos
# 書林          	書林          	PROPN 	5	flat:name
# ，           	，           	PUNCT 	5	punct
# 效職          	效職          	VERB  	12	advcl
# 文昌          	文昌          	PROPN 	8	obj
# ，           	，           	PUNCT 	12	punct
# 百寮          	百寮          	PROPN 	12	nsubj
# 傾           	傾           	VERB  	0	root
# 其           	其           	PRON  	14	nmod
# 雅範          	雅範          	PROPN 	12	obj
# ，           	，           	PUNCT 	17	punct
# 攝           	攝           	VERB  	17	compound
# 官           	官           	PART  	14	conj
# 藩部          	藩部          	PROPN 	17	appos
# ，           	，           	PUNCT 	22	punct
# 千里安         	千里安         	PROPN 	21	nmod
# 其           	其           	PRON  	22	nsubj
# 惠政          	惠政          	VERB  	3	parataxis
# 。           	。           	PUNCT 	12	punct
#
# [Sentence 12]
# 君積          	君積          	PROPN 	14	nsubj
# 潤           	潤           	PROPN 	1	flat:name
# 與           	與           	CCONJ 	6	cc
# 原           	原           	PART  	6	case
# ，           	，           	PUNCT 	6	punct
# 資芳          	資芳          	PROPN 	1	conj
# 桂苑          	桂苑          	PROPN 	6	flat:name
# ，           	，           	PUNCT 	9	punct
# 岐嶷          	岐嶷          	PROPN 	1	conj
# 夙表          	夙表          	PROPN 	9	flat:name
# ，           	，           	PUNCT 	1	punct
# 英           	英           	PROPN 	13	compound
# 徽           	徽           	PART  	14	nsubj
# 早發          	早發          	VERB  	0	root
# 。           	。           	PUNCT 	14	punct
#
# [Sentence 13]
# 徑           	徑           	NOUN  	2	compound
# 寸           	寸           	PART  	3	nsubj
# 稱           	稱           	VERB  	0	root
# 珍           	珍           	PROPN 	6	nmod
# ，           	，           	PUNCT 	6	compound
# 方           	方           	PART  	9	nsubj
# 魏車          	魏車          	PROPN 	6	appos
# 而           	而           	SCONJ 	9	mark
# 更重          	更重          	ADJ   	3	parataxis
# ，           	，           	PUNCT 	12	punct
# 盈尺          	盈尺          	NOUN  	12	nsubj
# 爲寳          	爲寳          	ADJ   	17	advcl
# ，           	，           	PUNCT 	12	punct
# 况           	况           	VERB  	17	advcl
# 秦城          	秦城          	PROPN 	14	obj
# 而           	而           	SCONJ 	17	mark
# 取貴          	取貴          	VERB  	3	parataxis
# 。           	。           	PUNCT 	3	punct
#
# [Sentence 14]
# 孝敬          	孝敬          	PROPN 	3	nmod
# 之           	之           	PART  	1	case
# 極           	極           	ADJ   	0	root
# ，           	，           	PUNCT 	11	punct
# 自           	自           	ADP   	6	case
# 叶           	叶           	PROPN 	3	nmod
# 天經          	天經          	PROPN 	6	flat:name
# ，           	，           	PUNCT 	11	punct
# 忠亮          	忠亮          	PROPN 	11	nmod
# 之           	之           	PART  	9	case
# 規           	規           	NOUN  	6	conj
# ，           	，           	PUNCT 	16	punct
# 非           	非           	PART  	14	case
# 緣           	緣           	NOUN  	15	compound
# 物           	物           	PART  	16	compound
# 獎           	獎           	PART  	6	appos
# 。           	。           	PUNCT 	3	punct
#
# [Sentence 15]
# 洎夫          	洎夫          	PROPN 	3	nsubj
# 鈎           	鈎           	PROPN 	1	flat:name
# 深致          	深致          	VERB  	0	root
# 遠           	遠           	PROPN 	3	obj
# ，           	，           	PUNCT 	10	punct
# 王室          	王室          	NOUN  	10	nsubj
# 與           	與           	CCONJ 	8	cc
# 銀           	銀           	PROPN 	6	conj
# 編           	編           	PROPN 	8	flat:name
# 並究          	並究          	VERB  	3	parataxis
# ，           	，           	PUNCT 	13	punct
# 屬           	屬           	PROPN 	13	nsubj
# 辭           	辭           	VERB  	10	parataxis
# 比事          	比事          	VERB  	13	xcomp
# ，           	，           	PUNCT 	18	punct
# 鸞           	鸞           	PROPN 	17	compound
# 光           	光           	PART  	18	nsubj
# 將           	將           	PROPN 	3	parataxis
# 鳳           	鳳           	PROPN 	18	appos
# 艷           	艷           	PROPN 	19	flat:name
# 相輝          	相輝          	PROPN 	19	flat:name
# 。           	。           	PUNCT 	3	punct
#
# [Sentence 16]
# 仁壽          	仁壽          	PROPN 	2	nmod
# 元年          	元年          	NOUN  	7	nmod:tmod
# ，           	，           	PUNCT 	2	punct
# 應           	應           	VERB  	7	advcl
# 詔舉          	詔舉          	PROPN 	4	obj
# ，           	，           	PUNCT 	4	punct
# 射策          	射策          	VERB  	0	root
# 甲第          	甲第          	VERB  	7	xcomp
# 。           	。           	PUNCT 	7	punct
#
# [Sentence 17]
# 時           	時           	PROPN 	2	nmod
# 漢           	漢           	PROPN 	10	nsubj
# 王           	王           	PROPN 	2	appos
# 諒           	諒           	PROPN 	3	flat:name
# 光           	光           	PROPN 	6	nmod
# 暦           	暦           	PROPN 	3	flat:name
# 寵命          	寵命          	PROPN 	6	flat:name
# ，           	，           	PUNCT 	3	punct
# 作牧          	作牧          	NOUN  	10	nsubj
# 參野          	參野          	VERB  	0	root
# 。           	。           	PUNCT 	10	punct
#
# [Sentence 18]
# 君以          	君以          	PROPN 	2	nmod
# 材地          	材地          	NOUN  	3	nsubj
# 兼           	兼           	VERB  	0	root
# 美           	美           	PROPN 	3	obj
# ，           	，           	PUNCT 	6	punct
# 解巾          	解巾          	PROPN 	4	conj
# 爲           	爲           	PUNCT 	10	punct
# 漢           	漢           	PROPN 	9	compound
# 府           	府           	PART  	10	nmod
# 典籤          	典籤          	NOUN  	4	conj
# 。           	。           	PUNCT 	3	punct
#
# [Sentence 19]
# 列長          	列長          	PROPN 	4	nmod
# 裾           	裾           	PROPN 	1	flat:name
# 之           	之           	PART  	1	case
# 賓           	賓           	PROPN 	0	root
# 從           	從           	ADP   	10	case
# ，           	，           	PUNCT 	10	punct
# 預           	預           	PART  	8	case
# 小山          	小山          	PROPN 	10	nmod
# 之           	之           	PART  	8	case
# 文藻          	文藻          	NOUN  	4	appos
# 。           	。           	PUNCT 	4	punct
#
# [Sentence 20]
# 高           	高           	PROPN 	0	root
# 視           	視           	PROPN 	1	flat:name
# 梧宫          	梧宫          	PROPN 	1	flat:name
# ，           	，           	PUNCT 	6	punct
# 孤標          	孤標          	PROPN 	6	compound
# 龍           	龍           	PART  	3	appos
# 岫           	岫           	PUNCT 	6	punct
# 。           	。           	PUNCT 	1	punct
#
# [Sentence 21]
# 及           	及           	CCONJ 	2	cc
# 燕謀          	燕謀          	PROPN 	10	nsubj
# 且           	且           	CCONJ 	4	cc
# 發           	發           	PROPN 	2	conj
# ，           	，           	PUNCT 	2	punct
# 人           	人           	NOUN  	7	nsubj
# 馳           	馳           	VERB  	10	advcl
# 成軫          	成軫          	PROPN 	7	obj
# 之           	之           	SCONJ 	7	mark:rel
# 辭           	辭           	VERB  	0	root
# ，           	，           	PUNCT 	15	punct
# 吴           	吴           	PROPN 	15	nsubj
# 兵           	兵           	PROPN 	12	flat:name
# 遂           	遂           	SCONJ 	15	mark
# 舉           	舉           	VERB  	10	parataxis
# ，           	，           	PUNCT 	18	punct
# 家           	家           	NOUN  	18	nsubj
# 上           	上           	VERB  	21	acl:relcl
# 周丘          	周丘          	PROPN 	18	obj
# 之           	之           	PART  	18	mark:rel
# 策           	策           	NOUN  	15	obj
# 。           	。           	PUNCT 	10	punct
#
# [Sentence 22]
# 君深          	君深          	PROPN 	2	compound
# 體           	體           	PART  	17	nsubj
# 逆           	逆           	VERB  	17	advcl
# 順           	順           	PROPN 	3	obj
# ，           	，           	PUNCT 	7	punct
# 妙達          	妙達          	PROPN 	7	compound
# 機兆          	機兆          	PART  	3	appos
# ，           	，           	PUNCT 	3	punct
# 屢           	屢           	ADV   	13	advmod
# 陳           	陳           	PROPN 	17	nsubj
# 忠講          	忠講          	PROPN 	10	flat:name
# ，           	，           	PUNCT 	10	punct
# 因致          	因致          	VERB  	17	advcl
# 猜嫌          	猜嫌          	VERB  	13	xcomp
# ，           	，           	PUNCT 	13	punct
# 遂           	遂           	SCONJ 	17	mark
# 以           	以           	VERB  	0	root
# 疾辭          	疾辭          	PROPN 	17	obj
# ，           	，           	PUNCT 	20	punct
# 免玆          	免玆          	PROPN 	17	obj
# 尤费          	尤费          	PROPN 	20	flat:name
# 。           	。           	PUNCT 	17	punct
#
# [Sentence 23]
# 於           	於           	VERB  	13	mark
# 是           	是           	AUX   	6	cop
# 韬           	韬           	PUNCT 	6	punct
# 光           	光           	PROPN 	6	compound
# 衡           	衡           	PROPN 	4	flat:name
# 泌           	泌           	PART  	13	nsubj
# ，           	，           	PUNCT 	6	punct
# 閉           	閉           	VERB  	13	advcl
# 想           	想           	VERB  	8	xcomp
# 簪           	簪           	PUNCT 	8	punct
# 纓           	纓           	PROPN 	9	obj
# ，           	，           	PUNCT 	8	punct
# 馳           	馳           	VERB  	0	root
# 驚           	驚           	PROPN 	16	nsubj
# 九           	九           	NUM   	16	obl
# 流           	流           	VERB  	18	acl:relcl
# 之           	之           	SCONJ 	16	mark:rel
# 宗           	宗           	NOUN  	13	obj
# ，           	，           	PUNCT 	25	punct
# 迴           	迴           	PROPN 	23	nsubj
# 翔           	翔           	PROPN 	20	flat:name
# 千           	千           	NUM   	23	obl
# 載           	載           	VERB  	25	acl:relcl
# 之           	之           	PART  	23	mark:rel
# 表           	表           	NOUN  	13	obj
# 。           	。           	PUNCT 	13	punct
#
# [Sentence 24]
# 氣           	氣           	PROPN 	3	nsubj
# 積           	積           	PROPN 	1	flat:name
# 星           	星           	PART  	0	root
# 頊           	頊           	PUNCT 	3	punct
# ，           	，           	PUNCT 	7	punct
# 神           	神           	NOUN  	3	conj
# 清林          	清林          	PROPN 	6	appos
# 澤           	澤           	PROPN 	7	flat:name
# 。           	。           	PUNCT 	3	punct
#
# [Sentence 25]
# 大業          	大業          	PROPN 	4	nsubj
# 中           	中           	ADP   	1	case
# ，           	，           	PUNCT 	1	punct
# 召補          	召補          	VERB  	0	root
# 左           	左           	PROPN 	7	nmod
# 武衛          	武衛          	PROPN 	7	compound
# 兵           	兵           	PART  	11	nsubj
# 曹           	曹           	PROPN 	7	appos
# ，           	，           	PUNCT 	8	punct
# 非           	非           	AUX   	11	cop
# 其好          	其好          	ADJ   	4	ccomp
# 也           	也           	PART  	4	discourse
# 。           	。           	PUNCT 	4	punct
#
# [Sentence 26]
# 乃           	乃           	PROPN 	21	nsubj
# 掛           	掛           	VERB  	6	advcl
# 冠獨          	冠獨          	PROPN 	2	obj
# 往           	往           	VERB  	6	advcl
# ，           	，           	PUNCT 	2	punct
# 逃難          	逃難          	VERB  	21	advcl
# 他           	他           	PRON  	8	compound
# 方           	方           	PART  	6	obj
# 。           	。           	PUNCT 	6	punct
# 爰           	爰           	PUNCT 	21	punct
# 屬           	屬           	PROPN 	21	nsubj
# 運           	運           	VERB  	21	advcl
# 初           	初           	PROPN 	12	obj
# ，           	，           	PUNCT 	12	punct
# 委身          	委身          	VERB  	21	advcl
# 從義          	從義          	PROPN 	15	obj
# ，           	，           	PUNCT 	15	punct
# 拜通議         	拜通議         	VERB  	21	advcl
# 大夫          	大夫          	PROPN 	18	obj
# ，           	，           	PUNCT 	18	punct
# 尋           	尋           	VERB  	0	root
# 除           	除           	VERB  	21	xcomp
# 監察          	監察          	VERB  	24	amod
# 御史          	御史          	NOUN  	22	obj
# 。           	。           	PUNCT 	21	punct
#
# [Sentence 27]
# 芬冠執憲        	芬冠執憲        	PROPN 	7	nsubj
# ，           	，           	PUNCT 	3	punct
# 霜簡          	霜簡          	PROPN 	1	appos
# 直筆          	直筆          	PROPN 	3	flat:name
# ，           	，           	PUNCT 	3	punct
# 志存          	志存          	VERB  	7	advcl
# 矯枉          	矯枉          	VERB  	9	advcl
# ，           	，           	PUNCT 	9	punct
# 情無          	情無          	VERB  	0	root
# 屈           	屈           	PROPN 	9	obj
# 橈           	橈           	PROPN 	10	flat:name
# 。           	。           	PUNCT 	7	punct
#
# [Sentence 28]
# 時           	時           	NOUN  	2	nsubj
# 以           	以           	VERB  	0	root
# 晉陽          	晉陽          	PROPN 	5	nmod
# 之           	之           	PART  	3	case
# 地           	地           	NOUN  	2	obj
# ，           	，           	PUNCT 	9	punct
# 王           	王           	PROPN 	9	nsubj
# 業           	業           	PROPN 	7	flat:name
# 攸基          	攸基          	VERB  	2	parataxis
# ，           	，           	PUNCT 	12	punct
# 餘寇          	餘寇          	PROPN 	12	nsubj
# 未平          	未平          	ADJ   	2	parataxis
# ，           	，           	PUNCT 	14	punct
# 嚴城          	嚴城          	PROPN 	12	nsubj
# 尚警          	尚警          	PROPN 	14	flat:name
# 。           	。           	PUNCT 	2	punct
#
# [Sentence 29]
# 口奉          	口奉          	PROPN 	3	nsubj
# 口           	口           	NOUN  	3	nsubj
# 巡撫          	巡撫          	VERB  	0	root
# ，           	，           	PUNCT 	5	punct
# 式光          	式光          	PROPN 	3	parataxis
# 原隰          	原隰          	PROPN 	5	flat:name
# 。           	。           	PUNCT 	3	punct
#
# [Sentence 30]
# 遵塗          	遵塗          	VERB  	0	root
# 北邁          	北邁          	PROPN 	1	obj
# ，           	，           	PUNCT 	1	punct
# 兇           	兇           	PROPN 	5	compound
# 黨           	黨           	PART  	6	nsubj
# 南侵          	南侵          	VERB  	1	parataxis
# ，           	，           	PUNCT 	6	punct
# 君潛          	君潛          	PROPN 	9	nsubj
# 運           	運           	VERB  	14	advcl
# 謀           	謀           	VERB  	9	xcomp
# 猷           	猷           	PROPN 	10	obj
# ，           	，           	PUNCT 	14	punct
# 星馳          	星馳          	PROPN 	14	nsubj
# 表檄          	表檄          	VERB  	1	parataxis
# 。           	。           	PUNCT 	1	punct
#
# [Sentence 31]
# 大軍          	大軍          	NOUN  	2	nsubj
# 既至          	既至          	VERB  	0	root
# ，           	，           	PUNCT 	15	punct
# 羣           	羣           	PROPN 	15	nsubj
# 袄           	袄           	PROPN 	4	flat:name
# 遂           	遂           	VERB  	15	advcl
# 口           	口           	NOUN  	6	obj
# ，           	，           	PUNCT 	6	punct
# 特降          	特降          	PROPN 	15	nsubj
# 璽書          	璽書          	PROPN 	9	flat:name
# ，           	，           	PUNCT 	6	punct
# 深加          	深加          	VERB  	15	advcl
# 慰喻          	慰喻          	VERB  	12	xcomp
# ，           	，           	PUNCT 	12	punct
# 進           	進           	VERB  	2	parataxis
# 授           	授           	VERB  	15	xcomp
# 輕車          	輕車          	NOUN  	18	nmod
# 都尉          	都尉          	NOUN  	16	obj
# 。           	。           	PUNCT 	2	punct
#
# [Sentence 32]
# 武德          	武德          	PROPN 	3	nmod
# 五           	五           	NUM   	3	nummod
# 年           	年           	NOUN  	5	nmod:tmod
# ，           	，           	PUNCT 	3	punct
# 轉           	轉           	VERB  	0	root
# 萬           	萬           	NUM   	8	nummod
# 年           	年           	NOUN  	6	clf
# 縣丞          	縣丞          	NOUN  	5	obj
# 。           	。           	PUNCT 	5	punct
#
# [Sentence 33]
# 帝城          	帝城          	PROPN 	3	nsubj
# 貴           	貴           	PROPN 	1	flat:name
# 要           	要           	AUX   	0	root
# ，           	，           	PUNCT 	7	punct
# 口謂          	口謂          	PROPN 	7	nmod
# 難           	難           	PROPN 	7	compound
# 繩           	繩           	PART  	1	appos
# ，           	，           	PUNCT 	10	punct
# 城里          	城里          	PROPN 	10	nmod
# 豪門          	豪門          	PROPN 	7	conj
# ，           	，           	PUNCT 	13	punct
# 尤多          	尤多          	PROPN 	13	nsubj
# 私謁          	私謁          	VERB  	3	parataxis
# 。           	。           	PUNCT 	3	punct
#
# [Sentence 34]
# 君抗          	君抗          	PROPN 	2	compound
# 心           	心           	PART  	9	nsubj
# 奉法          	奉法          	VERB  	9	advcl
# ，           	，           	PUNCT 	6	punct
# 正身          	正身          	PROPN 	6	nmod
# 直道          	直道          	NOUN  	9	nsubj
# ，           	，           	PUNCT 	6	punct
# 居職          	居職          	VERB  	9	advcl
# 累載          	累載          	VERB  	0	root
# ，           	，           	PUNCT 	12	punct
# 聲           	聲           	PROPN 	12	nsubj
# 譽           	譽           	VERB  	3	parataxis
# 甚隆          	甚隆          	ADJ   	12	xcomp
# 。           	。           	PUNCT 	3	punct
#
# [Sentence 35]
# 貞觀          	貞觀          	PROPN 	6	nmod
# 初           	初           	ADP   	1	case
# ，           	，           	PUNCT 	1	punct
# 遷洛州         	遷洛州         	PROPN 	6	nmod
# 長水          	長水          	PROPN 	6	nmod
# 縣令          	縣令          	NOUN  	0	root
# 。           	。           	PUNCT 	4	punct
#
# [Sentence 36]
# 中牟          	中牟          	PROPN 	2	nmod
# 德           	德           	PROPN 	10	nsubj
# 被           	被           	AUX   	10	aux:pass
# ，           	，           	PUNCT 	5	punct
# 遠慚馴雉        	遠慚馴雉        	PROPN 	10	nsubj
# ，           	，           	PUNCT 	7	punct
# 重泉          	重泉          	PROPN 	5	conj
# 政美          	政美          	PROPN 	7	flat:name
# ，           	，           	PUNCT 	5	punct
# 有           	有           	VERB  	0	root
# 娩           	娩           	VERB  	10	xcomp
# 翔驚          	翔驚          	PROPN 	11	obj
# 。           	。           	PUNCT 	10	punct
#
# [Sentence 37]
# 六           	六           	NUM   	2	nummod
# 年           	年           	NOUN  	6	nmod:tmod
# ，           	，           	PUNCT 	2	punct
# 遷蘇          	遷蘇          	PROPN 	5	compound
# 州           	州           	PART  	6	nmod
# 司馬          	司馬          	PROPN 	0	root
# 。           	。           	PUNCT 	6	punct
#
# [Sentence 38]
# 同彦          	同彦          	PROPN 	5	nmod
# 威           	威           	PROPN 	1	flat:name
# 之           	之           	PART  	1	case
# 稱           	稱           	VERB  	5	compound
# 職           	職           	PART  	7	nsubj
# ，           	，           	PUNCT 	5	punct
# 詛止          	詛止          	VERB  	0	root
# 文章          	文章          	NOUN  	7	obj
# ，           	，           	PUNCT 	19	punct
# 類           	類           	PART  	12	case
# 儒           	儒           	PROPN 	12	compound
# 宗           	宗           	PART  	14	nmod
# 之           	之           	PART  	12	case
# 納           	納           	PROPN 	19	nsubj
# 善           	善           	PROPN 	14	flat:name
# ，           	，           	PUNCT 	14	punct
# 實           	實           	ADV   	19	advmod
# 惟           	惟           	ADV   	19	advmod
# 忠肅          	忠肅          	PROPN 	7	parataxis
# 。           	。           	PUNCT 	5	punct
#
# [Sentence 39]
# 嗟乎          	嗟乎          	ADJ   	0	root
# 。           	。           	PUNCT 	1	punct
#
# [Sentence 40]
# 南康          	南康          	PROPN 	6	nsubj
# 仙           	仙           	PROPN 	1	flat:name
# 駕           	駕           	VERB  	6	advcl
# ，           	，           	PUNCT 	3	punct
# 未           	未           	ADV   	6	advmod
# 戾           	戾           	VERB  	0	root
# 於           	於           	VERB  	6	mark
# 三           	三           	NUM   	9	nummod
# 山           	山           	NOUN  	6	obj
# ，           	，           	PUNCT 	16	punct
# 壤口          	壤口          	PROPN 	16	nsubj
# 骥           	骥           	PROPN 	11	appos
# 足           	足           	PROPN 	12	flat:name
# ，           	，           	PUNCT 	11	punct
# 遠           	遠           	ADV   	16	advmod
# 輟           	輟           	VERB  	6	parataxis
# 於千          	於千          	VERB  	16	mark
# 里           	里           	NOUN  	16	obj
# 。           	。           	PUNCT 	6	punct
#
# [Sentence 41]
# 以貞觀十        	以貞觀十        	NUM   	6	nummod
# 年           	年           	NOUN  	1	clf
# 十一          	十一          	NUM   	6	nummod
# 月           	月           	NOUN  	3	clf
# 六           	六           	NUM   	6	nummod
# 日           	日           	NOUN  	13	nmod:tmod
# 終           	終           	ADV   	9	advmod
# 於官          	於官          	VERB  	9	compound
# 所           	所           	PART  	13	nsubj
# ，           	，           	PUNCT 	9	punct
# 年           	年           	NOUN  	13	nmod:tmod
# 六十          	六十          	NUM   	11	nummod
# 有           	有           	VERB  	0	root
# 一           	一           	NUM   	13	obj
# 。           	。           	PUNCT 	13	punct
#
# [Sentence 42]
# 夫人          	夫人          	NOUN  	0	root
# 隴           	隴           	PROPN 	5	nmod
# 西           	西           	NOUN  	2	acl
# 李           	李           	PROPN 	5	compound
# 氏           	氏           	PART  	1	appos
# ，           	，           	PUNCT 	9	punct
# 籍           	籍           	NOUN  	9	nsubj
# 慶           	慶           	PROPN 	9	nmod
# 高門          	高門          	PROPN 	1	parataxis
# ，           	，           	PUNCT 	13	punct
# 凝華          	凝華          	PROPN 	13	nsubj
# 中           	中           	PROPN 	13	compound
# 谷           	谷           	PART  	1	parataxis
# ，           	，           	PUNCT 	15	punct
# 貞           	貞           	PROPN 	1	appos
# 姿           	姿           	PROPN 	15	flat:name
# 玉映          	玉映          	PROPN 	15	flat:name
# ，           	，           	PUNCT 	19	punct
# 淑問          	淑問          	PROPN 	1	appos
# 風           	風           	PROPN 	19	flat:name
# 揚           	揚           	PROPN 	20	flat:name
# 。           	。           	PUNCT 	1	punct
#
# [Sentence 43]
# 粤           	粤           	PROPN 	11	nsubj
# 自           	自           	ADP   	3	case
# 移天          	移天          	PROPN 	11	obl
# ，           	，           	PUNCT 	3	punct
# 來           	來           	PROPN 	11	nsubj
# 儀           	儀           	PROPN 	5	flat:name
# 君子          	君子          	PROPN 	6	flat:name
# ，           	，           	PUNCT 	11	punct
# 懋           	懋           	PROPN 	11	nsubj
# 蘋           	蘋           	PROPN 	9	flat:name
# 繫           	繫           	VERB  	0	root
# 於           	於           	VERB  	11	mark
# 行潦          	行潦          	PROPN 	11	obj
# ，           	，           	PUNCT 	18	punct
# 諧           	諧           	PROPN 	18	nmod
# 瑟琴          	瑟琴          	PROPN 	15	flat:name
# 於異          	於異          	VERB  	18	compound
# 室           	室           	PART  	11	parataxis
# ，           	，           	PUNCT 	21	punct
# 女           	女           	NOUN  	18	nmod
# 圖           	圖           	PROPN 	20	appos
# 弘           	弘           	PROPN 	21	flat:name
# 訓           	訓           	PROPN 	21	flat:name
# ，           	，           	PUNCT 	25	punct
# 母德馳芳        	母德馳芳        	PROPN 	1	appos
# 。           	。           	PUNCT 	1	punct
#
# [Sentence 44]
# 與           	與           	ADP   	2	case
# 善           	善           	VERB  	0	root
# 何愆          	何愆          	PROPN 	2	obj
# ，           	，           	PUNCT 	2	punct
# 徂           	徂           	PROPN 	2	appos
# 光           	光           	PROPN 	5	flat:name
# 奄           	奄           	PROPN 	6	flat:name
# 謝           	謝           	PROPN 	6	flat:name
# 。           	。           	PUNCT 	2	punct
#
# [Sentence 45]
# 但           	但           	SCONJ 	18	mark
# 故鄉          	故鄉          	PROPN 	4	nmod
# 絶           	絶           	PROPN 	4	compound
# 人           	人           	PART  	18	nsubj
# ，           	，           	PUNCT 	4	punct
# 先望          	先望          	VERB  	11	advcl
# 遼遠          	遼遠          	PROPN 	6	obj
# ，           	，           	PUNCT 	6	punct
# 上下          	上下          	VERB  	11	advcl
# 諮           	諮           	PROPN 	9	obj
# 謀           	謀           	VERB  	18	advcl
# ，           	，           	PUNCT 	11	punct
# 改斯          	改斯          	PROPN 	18	nsubj
# 宅兆          	宅兆          	PROPN 	13	appos
# ，           	，           	PUNCT 	14	punct
# 爰卜邙洛        	爰卜邙洛        	PROPN 	13	appos
# ，           	，           	PUNCT 	14	punct
# 用定          	用定          	VERB  	0	root
# 終居          	終居          	VERB  	18	xcomp
# 。           	。           	PUNCT 	18	punct
#
# [Sentence 46]
# 粤           	粤           	PROPN 	10	nsubj
# 以           	以           	ADP   	9	case
# 永徽          	永徽          	PROPN 	9	nmod
# 六           	六           	NUM   	9	nummod
# 年           	年           	NOUN  	4	clf
# 十           	十           	NUM   	9	nummod
# 月           	月           	NOUN  	6	clf
# 一           	一           	NUM   	9	nummod
# 日           	日           	NOUN  	10	obl
# 合葬          	合葬          	VERB  	0	root
# 於           	於           	VERB  	10	mark
#
# [Sentence 47]
# 洛州          	洛州          	PROPN 	7	nmod
# 河南          	河南          	PROPN 	3	compound
# 縣           	縣           	PART  	7	nmod
# 平樂          	平樂          	PROPN 	5	compound
# 鄉           	鄉           	PART  	7	nmod
# 華邑          	華邑          	PROPN 	7	compound
# 里           	里           	PART  	9	nmod
# 邙           	邙           	PROPN 	9	compound
# 山           	山           	PART  	11	nmod
# 之           	之           	PART  	9	case
# 原           	原           	NOUN  	0	root
# 。           	。           	PUNCT 	11	punct
#
# [Sentence 48]
# 嗚           	嗚           	PROPN 	2	nsubj
# 呼           	呼           	VERB  	16	advcl
# 哀           	哀           	PROPN 	2	obj
# 哉           	哉           	PROPN 	3	flat:name
# 。           	。           	PUNCT 	2	punct
# 迺           	迺           	PROPN 	16	nsubj
# 爲           	爲           	PROPN 	6	flat:name
# 銘           	銘           	PROPN 	6	flat:name
# 曰           	曰           	PROPN 	8	flat:name
# ：           	：           	PUNCT 	12	punct
# 天齊          	天齊          	PROPN 	12	compound
# 形           	形           	PART  	6	appos
# 勝           	勝           	VERB  	16	advcl
# ，           	，           	PUNCT 	13	punct
# 投釣          	投釣          	VERB  	16	advcl
# 開封          	開封          	VERB  	0	root
# 。           	。           	PUNCT 	16	punct
#
# [Sentence 49]
# 長           	長           	PART  	2	case
# 岑           	岑           	PROPN 	0	root
# 博雅          	博雅          	PROPN 	2	flat:name
# ，           	，           	PUNCT 	6	punct
# 弈葉          	弈葉          	PROPN 	6	nmod
# 雕龍          	雕龍          	NOUN  	2	appos
# 。           	。           	PUNCT 	2	punct
#
# [Sentence 50]
# 懷           	懷           	PROPN 	6	nsubj
# 金           	金           	PROPN 	1	flat:name
# 鏘玉          	鏘玉          	PROPN 	1	flat:name
# ，           	，           	PUNCT 	1	punct
# 疊           	疊           	PROPN 	1	flat:name
# 構           	構           	VERB  	0	root
# 連峰          	連峰          	PROPN 	6	obj
# 。           	。           	PUNCT 	6	punct
#
# [Sentence 51]
# 森梢          	森梢          	PROPN 	0	root
# 良梓          	良梓          	PROPN 	1	flat:name
# ，           	，           	PUNCT 	4	punct
# 磊落          	磊落          	PROPN 	1	appos
# 喬松          	喬松          	PROPN 	4	flat:name
# 。           	。           	PUNCT 	1	punct
#
# [Sentence 52]
# 惟           	惟           	SCONJ 	3	mark
# 祖惟          	祖惟          	PROPN 	3	nsubj
# 考           	考           	VERB  	0	root
# ，           	，           	PUNCT 	7	punct
# 道風          	道風          	NOUN  	7	nsubj
# 逾           	逾           	ADV   	7	advmod
# 盛           	盛           	ADJ   	3	parataxis
# 。           	。           	PUNCT 	3	punct
#
# [Sentence 53]
# 績表          	績表          	VERB  	2	compound
# 遺           	遺           	PART  	3	compound
# 縑           	縑           	PART  	0	root
# ，           	，           	PUNCT 	5	punct
# 息孚          	息孚          	PROPN 	3	appos
# 留詠          	留詠          	PROPN 	5	flat:name
# 。           	。           	PUNCT 	3	punct
#
# [Sentence 54]
# 懿           	懿           	PROPN 	5	nsubj
# 哉           	哉           	PROPN 	1	flat:name
# 君子          	君子          	PROPN 	1	flat:name
# ，           	，           	PUNCT 	1	punct
# 誕           	誕           	VERB  	0	root
# 膺           	膺           	VERB  	5	mark
# 家慶          	家慶          	PROPN 	6	obj
# 。           	。           	PUNCT 	5	punct
#
# [Sentence 55]
# 具           	具           	VERB  	7	advcl
# 美           	美           	PROPN 	1	obj
# 攸鍾          	攸鍾          	PROPN 	2	appos
# ，           	，           	PUNCT 	1	punct
# 多           	多           	ADV   	7	advmod
# 能           	能           	AUX   	7	aux
# 無競          	無競          	VERB  	0	root
# 。           	。           	PUNCT 	7	punct
#
# [Sentence 56]
# 始口          	始口          	PROPN 	2	nsubj
# 窮           	窮           	VERB  	3	advcl
# 運           	運           	VERB  	0	root
# ，           	，           	PUNCT 	6	punct
# 終           	終           	ADV   	6	advmod
# 會           	會           	PART  	3	parataxis
# 昌辰          	昌辰          	PROPN 	6	appos
# 。           	。           	PUNCT 	3	punct
#
# [Sentence 57]
# 蘭           	蘭           	PROPN 	3	nsubj
# 臺           	臺           	PROPN 	1	flat:name
# 振操          	振操          	VERB  	0	root
# ，           	，           	PUNCT 	6	punct
# 赤縣          	赤縣          	PROPN 	6	nmod
# 霑口          	霑口          	NOUN  	3	parataxis
# 。           	。           	PUNCT 	3	punct
#
# [Sentence 58]
# 牛刀          	牛刀          	NOUN  	5	nsubj
# 暫           	暫           	ADV   	3	advmod
# 屈           	屈           	VERB  	5	advcl
# ，           	，           	PUNCT 	3	punct
# 驟           	驟           	VERB  	0	root
# 足           	足           	PROPN 	5	obj
# 俄申          	俄申          	PROPN 	6	flat:name
# 。           	。           	PUNCT 	5	punct
#
# [Sentence 59]
# 上           	上           	NOUN  	6	nmod:tmod
# 才           	才           	SCONJ 	6	mark
# 方遠          	方遠          	PROPN 	6	nsubj
# ，           	，           	PUNCT 	1	punct
# 高春遽         	高春遽         	PROPN 	6	nsubj
# 淪           	淪           	VERB  	0	root
# 。           	。           	PUNCT 	6	punct
#
# [Sentence 60]
# 猗           	猗           	PROPN 	3	nsubj
# 歟           	歟           	PROPN 	1	flat:name
# 令偶          	令偶          	VERB  	0	root
# ，           	，           	PUNCT 	5	punct
# 蕙心          	蕙心          	PROPN 	3	parataxis
# 瓊潔          	瓊潔          	PROPN 	5	flat:name
# 。           	。           	PUNCT 	3	punct
#
# [Sentence 61]
# 昔奉          	昔奉          	VERB  	12	advcl
# 齊眉          	齊眉          	PROPN 	1	obj
# ，           	，           	PUNCT 	1	punct
# 今           	今           	NOUN  	5	nmod:tmod
# 歸           	歸           	VERB  	12	advcl
# 同穴          	同穴          	PROPN 	5	obj
# 。           	。           	PUNCT 	5	punct
# 口旗          	口旗          	PROPN 	9	nmod
# 縈委          	縈委          	NOUN  	12	nsubj
# ，           	，           	PUNCT 	5	punct
# 口扉          	口扉          	VERB  	12	advcl
# 冥滅          	冥滅          	VERB  	0	root
# 。           	。           	PUNCT 	12	punct
#
# [Sentence 62]
# 去           	去           	VERB  	0	root
# 矣佳          	矣佳          	PROPN 	3	compound
# 城           	城           	PART  	1	obj
# ，           	，           	PUNCT 	5	punct
# 悠哉芳烈        	悠哉芳烈        	PROPN 	3	conj
# 。           	。           	PUNCT 	1	punct

# %% [markdown]
# Alternatively, you can directly print a `Word` object to view all its annotations as a Python dict:

# %%
word = en_doc.sentences[0].words[0]
print(word)

# %% [markdown]
# ### More Information
#
# For all information on different data objects, please visit our [data objects page](https://stanfordnlp.github.io/stanza/data_objects.html).

# %% [markdown]
# ## 5. Resources
#
# Apart from this interactive tutorial, we also provide tutorials on our website that cover a variety of use cases such as how to use different model "packages" for a language, how to use spaCy as a tokenizer, how to process pretokenized text without running the tokenizer, etc. For these tutorials please visit [our Tutorials page](https://stanfordnlp.github.io/stanza/tutorials.html).
#
# Other resources that you may find helpful include:
#
# - [Stanza Homepage](https://stanfordnlp.github.io/stanza/index.html)
# - [FAQs](https://stanfordnlp.github.io/stanza/faq.html)
# - [GitHub Repo](https://github.com/stanfordnlp/stanza)
# - [Reporting Issues](https://github.com/stanfordnlp/stanza/issues)
# - [Stanza System Description Paper](http://arxiv.org/abs/2003.07082)
